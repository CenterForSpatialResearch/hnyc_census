# %%
#import the packages that needed
import pandas as pd
import numpy as np
import regex as re
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# regular expression in R:
# - https://rstudio-pubs-static.s3.amazonaws.com/74603_76cd14d5983f47408fdf0b323550b846.html
# - https://cran.r-project.org/web/packages/stringr/vignettes/regular-expressions.html
#
# regular expression in Python:
# - https://www.bogotobogo.com/python/python_regularExpressions.php#:~:text=Well%2C%20%5CD%20matches%20any%20character,try%20to%20match%20different%20separators.
#
# Quite useful regular expression extract web:
# - https://regex101.com/r/rzNgTL/1

# %%
# pattern = re.compile(r'\sSTREET$|\sSRT$|\sSR$\s|SRT$|\sSST$|\sSEET|\sTREET|\sSHEER|\sSHEE|\sSTREE|\sSREET|\sREET|\sSTEE|\sST')
# re.sub(pattern, " ST", "511 West 112th STREET")

# pattern = re.compile(r'\sN\s')
# re.sub(pattern, " N ", "511 N 112th STREET")

# pattern = re.compile(r'\sDRIVE$|\sDR$|\sDV$|\sDE$|\sDRV$|\sDRI$|\sDRIV$|\sDRIE$')
# x = re.sub(pattern, " DR", "528 Rivderside DRIVE")

# pattern = re.compile(r"\d+\s") # perl = true not sure
# x = re.sub(pattern, "", "528 Riverside")

# pattern = re.compile(r".*\s(.*)\s.*") 
# x = re.sub(pattern, " 1", "528 Riverside")

# pattern = re.compile(r"[^\w\s]")
# x = re.sub(pattern, "", "528 Ri?v.e*r#si-de")

# pattern = re.compile(r"(\d)(ST|ND|RD|TH)\b")
# x = re.sub(pattern, "1", "511 West 112TH St.")

# pattern = re.compile(r'(\w+|\d+)\s(\bN\b|\bW\b|\bS\b|\bE\b)')
# x = re.sub(pattern, r'\2 \1', "4 W")

# pattern = re.compile(r'(AVE)\s((\d)|[A-Z].)')
# x = re.sub(pattern, r'\2 \1', 'AVE BS')   

# pattern = re.compile(r"\s1ST|\b1\b|(\s|^)FIRST|\sFRST|\sFIRST|\sONE|\s(ONE HUNDRED)|\sONEHUNDRED|\sHUNDRED|\sHUDRED|\sHUNDED") 
# x = re.sub(pattern, "1", "FIRST street") 

# pattern = re.compile(r"(\s|^)(FIFTH)\b")
# x = re.sub(pattern, r"\g<1>5", 'EAST FIFTH STREET')
# x

# pattern = re.compile(r'(\w+|\d+)\s(\bN\b|\bW\b|\bS\b|\bE\b)')
# b = re.sub(pattern, r'\2 \1', 'AVE A')
# pattern = re.compile(r'(AVE)\s\d|(AVE)\s[A-Z]')
# c = re.sub(pattern, r'\2 \1', 'AVE A') 
# pattern = re.compile(r'(AVE)\s((\d)|[A-Z])')
# d = re.sub(pattern, r'\2 \1', 'AVE A') 

# print(b)
# print(c)
# print(d)

# pattern = re.compile(r'(AVE)\s(\b[A-Z])')
# x = re.sub(pattern, r'\2 \1', 'AMSTERDAM AVE 190-195 ST') 
# x

# pattern = re.compile(r'(AVE)\s(\d+)')
# x = re.sub(pattern, r'\2 \1', 'AMSTERDAM AVE 190-195 ST') 
# x

# pattern = re.compile(r'(AVE)\s(\d+\sTO\s\d+)')
# x = re.sub(pattern, r'\2 \1', 'AMSTERDAM AVE 135 TO 138 STE') 

# pattern = re.compile(r"\s(TO)\s") 
# x = re.sub(pattern, "-", 'AMSTERDAM AVE 135 TO 138 STE')

# pattern = re.compile(r'\sSTREET$|STREET|\sSTR$|\sSTE$|\sSRT$|\sSR$\s|SRT$|\sSST$|\sSEET|\sTREET|\sSHEER|\sSHEE|\sSTREE.|\sSREET|\sREET|\sSTEE|\sST')
# x = re.sub(pattern, " ST", '99TH STREET BETWEEN CP WEST & CO')
# print(x)
# pattern1 = re.compile(r"\sST") # perl = true
# y = re.sub(pattern1, "", x)# remove ST after space
# print(y)
# pattern2 = re.compile(r'(\d+)(ST|ND|RD|TH)\b')
# z = re.sub(pattern2, r'\1', y) 
# print(z)

# pattern = re.compile(r'\sSTREET$|STREET|\sSTR$|\sSTE$|\sSRT$|\sSR$\s|SRT$|\sSST$|\sSEET|\sTREET|\sSHEER|\sSHEE|\sSTREE.|\sSREET|\sREET|\sSTEE|\sST')
# x = re.sub(pattern, " ST", 'EAST NINTH STREET')
# print(x)
# pattern = re.compile(r"(\s|^)9TH|\b9\b|(\s|^)UNITY|NINTH|(\s|^)NINETY|(\s|^)NINETEY|(\s|^)NINETIETH|(\s|^)NINTY") 
# y = re.sub(pattern, "9", x)
# print(y)

pattern = re.compile(r"(\s|^)4TH|\b4\b|(\s|^)FORT(Y|H)|(\s|^)FRTY|(\s|^)FROTH|(\s|^)FROUTH|FOUR\D+") 
x = re.sub(pattern, "4", 'WEST FOURTY NINTH STREET') 
x
# Out:
# 'WEST 4'

# %%
# # clean function check

# def clean(x):
#     # change the format to all upper
#     x = str(x.upper())
    
# #     pattern = re.compile(r'\sSTREET$|STREET|\sSTR$|\sSTE$|\sSRT$|\sSR$\s|SRT$|\sSST$|\sSEET|\sTREET|\sSHEER|\sSHEE|\sSTREE.|\sSREET|\sREET|\sSTEE|\sST')
# #     x = re.sub(pattern, " ST", x)
#     pattern = re.compile(r'\sSTREET\b|\bSTREET|\sSTR$|\sSTE$|\sSRT$|\sSR$\s|SRT$|\sSST$|\sSEET|\sTREET|\sSHEER|\sSHEE|\sSTREE\b|\sSREET|\sREET|\sSTEE|\sST')
#     x = re.sub(pattern, " ST", x)

#     # The orientations in the addresses
#     pattern = re.compile(r'\sN\s')
#     re.sub(pattern, " N ", x)
#     pattern = re.compile(r'\sS\s')
#     re.sub(pattern, " S ", x)
#     pattern = re.compile(r'\sE\s')
#     re.sub(pattern, " E ", x)
#     pattern = re.compile(r'\sW\s')
#     re.sub(pattern, " W ", x)
    
#     # deal with the end of the addresses
#     pattern = re.compile(r'\sDRIVE$|\sDR$|\sDV$|\sDE$|\sDRV$|\sDRI$|\sDRIV$|\sDRIE$')
#     x = re.sub(pattern, " DR", x)
#     pattern = re.compile(r'\sCIRCLE|\sCIR|\sCRL|\sCIRC|\sCR|\sCL|\sCIRCL|\sCICLE')
#     x = re.sub(pattern, " CIR", x)
#     pattern = re.compile(r'(\s|^)AVENUE|(\s|^)AVE|(\s|^)AV|(\s|^)AVN|(\s|^)AVEN|(\s|^)AVENU')
#     x = re.sub(pattern, " AVE", x)
#     pattern = re.compile(r"(?<=\s)COURT|CT|CRT|CRT|CTR|(?<=\s)COUR|(?<=\s)COT|(?<=\s)CORT")
#     x = re.sub(pattern, " CT", x)
# #     pattern = re.compile(r"\sBOULEVARD|\sBLVD|\sBVLD|\sBV|\sBLD|\sBD|\sBL|\sBLV")
# #     x = re.sub(pattern, " BLVD", x)
#     pattern = re.compile(r"\sBOULEVARD|\sBVLD|\sBV|\sBLD$|\sBD|\sBL$|\sBLV$")
#     x = re.sub(pattern, " BLVD", x)
#     pattern = re.compile(r"\sROAD|\sRD|\sRAD|\sROD")
#     x = re.sub(pattern, " RD", x)
#     pattern = re.compile(r"\sALLEY|\sALY|\sAL|\sALLY|\sALEY|\sALLE|\sAY")
#     x = re.sub(pattern, " ALY", x)
#     pattern = re.compile(r"\sPLACE|\sPL|\sPLC|\sPLE|\sPC|\sPLAC|\sPLCE|\sPCE")
#     x = re.sub(pattern, " PL", x)
#     pattern = re.compile(r"\sPK|\sPRK|\sPRAK|\sPAK")
#     x = re.sub(pattern, " PARK", x)
#     pattern = re.compile(r"\sPARKWAY|\sPKWY|\sPARKW|\sPWY|\sPKW|\sPRKWY|\sPKWY|\sPKW")
#     x = re.sub(pattern, " PKWY", x)
#     pattern = re.compile(r"\sAPPR|\sAPR|\sAPPROA|\sAPRCH|\sAPPRCH")
#     x = re.sub(pattern, " APPROACH", x)
#     pattern = re.compile(r"\sTERRACE|\sTER|\sTERR|\sTRC|\sTRCE|\sTR")
#     x = re.sub(pattern, " TER", x)
#     pattern = re.compile(r"\sPLAZA|\sPLZ|\sPLAZ|\sPZ|\sPLZA")
#     x = re.sub(pattern, " PLZ", x)
#     pattern = re.compile(r"\sLANE|\sLN|\sLNE|\sLAN")
#     x = re.sub(pattern, " LN", x)
# #     pattern = re.compile(r"\sBRIDGE|\sBRG|\sBRGD|\sBGE")
# #     x = re.sub(pattern, " BRG",x)
#     pattern = re.compile(r"\sHILL|\sHL|\sHLL|\sHIL")
#     x = re.sub(pattern, " HL", x)
#     pattern = re.compile(r"\sHEIGHTS|\sHTS|\sHT|\sHEIGHT|\sHEGHTS|\sHHT|\sHEIGT") 
#     x = re.sub(pattern, " HTS", x)
#     pattern = re.compile(r"\sSLP|\sSLEP|\sSLIIP|\sSLI")
#     x = re.sub(pattern, " SLIP", x)
#     pattern = re.compile(r"\sRON|\sRW|\sROE|\sROOW")
#     x = re.sub(pattern, " ROW", x)
#     pattern = re.compile(r"\sSQUARE") 
#     x = re.sub(pattern, " SQ", x)
    

# #     x<-gsub(".*\\((.*)\\).*", "\\1", x)
# #     x<-gsub("(?<=\\s)(ST)","",x, perl = TRUE) #remove ST after space
# #     x<-gsub("\\d+\\ - *\\d*|\\d+\\ TO *\\d*|\\d+\\-\\d*","",x) #remove addresses
    
# #     pattern = re.compile(r".*\s(.*)\s.*")
# #     x = re.sub(pattern, r"\1", x)
#     pattern = re.compile(r"\sST$") # perl = true
#     x = re.sub(pattern, "", x)# remove ST after space
# #     pattern = re.compile(r"\d+\s") 
# #     x = re.sub(pattern, "", x) # remove addresses
    
#     # deal with special characters (\;';*'.')
#     pattern = re.compile(r"\s(TO)\s") 
#     x = re.sub(pattern, "-", x)
#     pattern = re.compile(r"-") 
#     x = re.sub(pattern, " ", x)
#     pattern = re.compile(r"&") 
#     x = re.sub(pattern, "AND", x)
#     pattern = re.compile(r"[^\w\s]") 
#     x = re.sub(pattern, "", x)  
    
#     # dealing with numbered streets
#     pattern = re.compile(r"(?<=[0-9])(ST|ND|RD|TH)")
#     x = re.sub(pattern, "", x)
#     pattern = re.compile(r"(\d+)(ST|ND|RD|TH)\b")
#     x = re.sub(pattern, r"\1", x)
#     pattern = re.compile(r"(\s|^)1ST|\b1\b|(\s|^)FRIST|(\s|^)FRST|(\s|^)FIRST|(\s|^)ONE|\bONE\sHUNDRED|(\s|^)ONEHUNDRED|(\s|^)HUNDRED|(\s|^)HUDRED|(\s|^)HUNDED") 
#     x = re.sub(pattern, "1", x) 
#     pattern = re.compile(r"(\s|^)TWO\sHUNDRED|(\s|^)TWOHUNDRED|(\s|^)2ND|(\s|^)TWENTY|(\s|^)TWENTI|(\s|^)TENTI|(\s|^)SECOND|(\s|^)SECORD|(\s|^)SCOND|(\s|^)TWO") 
#     x = re.sub(pattern, "2", x)
# #     pattern = re.compile(r"(\s|^)TWO\sHUNDRED|(\s|^)TWOHUNDRED|(\s|^)2ND|(\s|^)TWENTY|(\s|^)TWENTI|(\s|^)TENTI|(\s|^)SECOND|(\s|^)SECORD|(\s|^)SCOND|(\s|^)TWO") 
# #     x = re.sub(pattern, "2", x)
#     pattern = re.compile(r"(\s|^)3RD|\b3\b|(\s|^)THIRTY|(\s|^)THIRTHY|(\s|^)THIRTEY|(\s|^)TIRTY|(\s|^)TRITHY|(\s|^)THRID|(\s|^)THIRD|(\s|^)TIRD|(\s|^)TRIH|(\s|^)THREE") 
#     x = re.sub(pattern, "3", x)    
# #     pattern = re.compile(r"(\s|^)4TH|\b4\b|(\s|^)FORT(Y|H)|(\s|^)FOUR(TH|TY|THY)|(\s|^)FRTY|(\s|^)FROTH|(\s|^)FROUTH|(\s|^)FOUR") 
# #     x = re.sub(pattern, "4", x) 
#     pattern = re.compile(r"(\s|^)4TH|\b4\b|(\s|^)FORT(Y|H)|\bFOURTHY.|\bFOURT.|(\s|^)FRTY|(\s|^)FROTH|(\s|^)FROUTH|\bFOUR\s") 
#     x = re.sub(pattern, "4", x)
#     pattern = re.compile(r"(\s|^)5TH|\b5\b|(\s|^)FIFTY|(\s|^)FIFTEY|\sFIFT.|\sFITY|(\s|^)FIFTHY|(\s|^)FIFETH|(\s|^)(FIFTH)|(\s|^)FIFFTH|(\s|^)FIFTHE|(\s|^)FIVE") 
#     x = re.sub(pattern, "5", x)
#     pattern = re.compile(r"(\s|^)6TH|\b6\b|(\s|^)(SIXTY)|(\s|^)(SXTY)|(\s|^)(SIXY)|(\s|^)(SXTY)|(\s|^)(SIXTHY)|(\s|^)(SIXTEY)|SIXTH|(\s|^)(SXTH)|(\s|^)(SITH)|(\s|^)(SIHXT)|(\s|^)(SIX)\b") 
#     x = re.sub(pattern, "6", x)
# #     pattern = re.compile(r"(\s|^)7TH|\b7\b|\sSEVENT\s|(\s|^)SEVENTY|(\s|^)SEVENTEY|(\s|^)SVENTY|(\s|^)SEVENTI|(\s|^)SEVENTH|\sSVEN|(\s|^)SVENTH|(\s|^)SEVENH|\bSEVEN") 
# #     x = re.sub(pattern, "7", x) 
#     pattern = re.compile(r"(\s|^)7TH|\b7\b|\sSEVENT\s|(\s|^)SEVENTY|(\s|^)SEVENTEY|(\s|^)SVENTY|(\s|^)SEVENTI|(\s|^)SEVENTH|\sSVEN|(\s|^)SVENTH|(\s|^)SEVENH|\bSEVEN") 
#     x = re.sub(pattern, "7", x) 
#     pattern = re.compile(r"\s8TH|\b8\b|(\s|^)EIGHTY|(\s|^)EIGHTEY|(\s|^)EIGHTE|(\s|^)EIGHTH|(\s|^)EIGHTEH|(\s|^)EITH|(\s|^)EIGHT|(\s|^)EIGHTTH|(\s|^)EIGTH|(\s|^)FIGHT") 
#     x = re.sub(pattern, "8", x)       
# #     pattern = re.compile(r"(\s|^)9TH|\b9\b|(\s|^)UNITY|NINTH|(\s|^)NINETY|(\s|^)NINETEY|(\s|^)NINETIETH|(\s|^)NINTY") 
# #     x = re.sub(pattern, "9", x) 
#     pattern = re.compile(r"(\s|^)9TH|\b9\b|(\s|^)UNITY|\bNINTH|(\s|^)NINETY|(\s|^)NINETEY|(\s|^)NINETIETH|(\s|^)NINTY") 
#     x = re.sub(pattern, "9", x) 
#     pattern = re.compile(r"(\s|^)10TH|\b10\b|\bTENTH\b") 
#     x = re.sub(pattern, "10", x)     
#     pattern = re.compile(r"(\s|^)11TH|\b11\b|(\s|^)ELEVENTH") 
#     x = re.sub(pattern, "11", x)
#     pattern = re.compile(r"(\s|^)12TH|\b12\b|(\s|^)TWELFTH") 
#     x = re.sub(pattern, "12", x)    
#     pattern = re.compile(r"(\s|^)13TH|\b13\b|(\s|^)THIRTEENTH") 
#     x = re.sub(pattern, "13", x)     
#     pattern = re.compile(r"(\s|^)14TH|\b14\b|(\s|^)FORTEENTH") 
#     x = re.sub(pattern, "14", x)    
#     pattern = re.compile(r"(\s|^)15TH|\b15\b|(\s|^)FIFTEENTH") 
#     x = re.sub(pattern, "15", x)
#     pattern = re.compile(r"(\s|^)16TH|\b16\b|(\s|^)SIXTEENTH") 
#     x = re.sub(pattern, "16", x)
#     pattern = re.compile(r"(\s|^)17TH|\b17\b|(\s|^)SEVENTEENTH") 
#     x = re.sub(pattern, "17", x)
#     pattern = re.compile(r"(\s|^)18TH|\b18\b|(\s|^)EIGHTEENTH") 
#     x = re.sub(pattern, "18", x)
#     pattern = re.compile(r"(\s|^)19TH|\b19\b|(\s|^)NINETEENTH") 
#     x = re.sub(pattern, "19", x)
#     pattern = re.compile(r"(\s|^)TWENTIETH|(\s|^)TWENTIEFTH") 
#     x = re.sub(pattern, "20", x)
#     pattern = re.compile(r"(\s|^)THIRTIETH|(\s|^)THIRTIEFTH") 
#     x = re.sub(pattern, "30", x)
#     pattern = re.compile(r"(\s|^)FORTIETH|(\s|^)FOURTIETH|(\s|^)FOURTHENTH") 
#     x = re.sub(pattern, "40", x)
#     pattern = re.compile(r"(\s|^)FIFTIETH") 
#     x = re.sub(pattern, "50", x)
#     pattern = re.compile(r"\b(\s|^)(SIXTIETH)\b") 
#     x = re.sub(pattern, " 60", x)
#     pattern = re.compile(r"\bSEVENTIETH|(\s|^)SEVENTY") 
#     x = re.sub(pattern, "70", x)    
#     pattern = re.compile(r"(\s|^)EIGHTIETH|(\s|^)EIGHTETH") 
#     x = re.sub(pattern, "80", x) 
#     pattern = re.compile(r"(\s|^)NINETIETH|(\s|^)NINTIETH") 
#     x = re.sub(pattern, "90", x) 
# #     pattern = re.compile(r"(?<=\d)(?=\d)") # postive look-behind assertion & positive look-ahead assertion
# #     x = re.sub(pattern, "", x) 
#     pattern = re.compile(r'^\bST\b')
#     x = re.sub(pattern, "SAINT", x)
# #     pattern = re.compile(r'\bHOUSE\b|\bHOSTEL\b|HOTEL|\bLODGE\b|\bLODGING\b')
# #     x = re.sub(pattern,"", x)
#     pattern = re.compile(r'\sHOUSE|\sHOSTEL|\sHOTEL|\sLODGE|\sLODGING')
#     x = re.sub(pattern,"", x)

#     # overall spacing problem extra white space
#     pattern = re.compile(r'((\w+|\d+)\s\s(\w+|\d+))|((\w+|\d+)\s\s\s(\w+|\d+))')
#     x = re.sub(pattern, r"\1 \2", x)

# # x <- gsub("((\\w+|\\d+)\\s\\s(\\w+|\\d+))", "\\2 \\3", x)
# # x <- gsub("((\\w+|\\d+)\\s\\s\\s(\\w+|\\d+))", "\\2 \\3", x)
    
#     # change the order of the address, e.g: 4 W to W 4 & AVE after A-Z and Digits
#     pattern = re.compile(r'(\w+|\d+)\s(\bN\b|\bW\b|\bS\b|\bE\b)')
#     x = re.sub(pattern, r'\2 \1', x)
# #     pattern = re.compile(r'(AVE)\s\d|(AVE)\s[A-Z])')
# #     x = re.sub(pattern, r'\2 \1', x) 
# #     pattern = re.compile(r'(AVE)\s(\d+\sTO\s\d+)')
# #     x = re.sub(pattern, r'\2 \1', x) 
#     pattern = re.compile(r'(AVE)\s(\d+)\s(\d+)')
#     x = re.sub(pattern, r'\2-\3 \1', x) 
#     pattern = re.compile(r'(AVE)\s([A-Z])')
#     x = re.sub(pattern, r'\2 \1', x) 
# #     pattern = re.compile(r'(AVE)\s(\b[A-Z])')
# #     x = re.sub(pattern, r'\2 \1', x) 

#     ###### ALL MANUAL CLEANING GOES BELOW HERE ######
#     # Manual Cleaning
#     pattern = re.compile(r'(\s|^)ALLANTIC|(\s|^)ATLASTA')
#     x = re.sub(pattern, "ATLANTIC", x)
#     pattern = re.compile(r'(\s|^)ALLEM')
#     x = re.sub(pattern, "ALLEN", x)    
# #     pattern = re.compile(r'(\s|^)ANENUE')
# #     x = re.sub(pattern, "AVE", x)    
#     pattern = re.compile(r'(\s|^)CROTON|(\s|^)GROTON')
#     x = re.sub(pattern, "AUDUBON", x)    
#     pattern = re.compile(r'(\s|^)(AT RINS)')
#     x = re.sub(pattern, "ATKINS", x)     
    
#     pattern = re.compile(r'(\s|^)BATTIE')
#     x = re.sub(pattern, "BALTIC", x)      
#     pattern = re.compile(r'(\s|^)BARREE')
#     x = re.sub(pattern, "BARROW", x)   
#     pattern = re.compile(r'(\s|^)BESSHLEY')
#     x = re.sub(pattern, "BURLING", x)       
#     pattern = re.compile(r'(\s|^)BIRY|(\s|^)(B WAY)|(\s|^)BWAY|(\s|^)BRAKSWAY')
#     x = re.sub(pattern, "BROADWAY", x)         
#     pattern = re.compile(r'(\s|^)BUSTWICK')
#     x = re.sub(pattern, "BUSHWICK", x) 
#     pattern = re.compile(r'(\s|^)BUTTER')
#     x = re.sub(pattern, "BUTLER", x) 
#     pattern = re.compile(r'(\s|^)BREEVORT')
#     x = re.sub(pattern, "BREVOORT", x) 
#     pattern = re.compile(r'(\s|^)BRENNEL|\sBROOMES\s|\sBROOM|(\s|^)BRANNAS|(\s|^)BROWN')
#     x = re.sub(pattern, "BROOME", x) 
#     pattern = re.compile(r'(\s|^)BLACKER|(\s|^)BLENKER')
#     x = re.sub(pattern, "BLEECKER", x) 
    
#     pattern = re.compile(r'(\s|^)CLAIR')
#     x = re.sub(pattern, "CLASSON", x) 
#     pattern = re.compile(r'(\s|^)CLISTEN')
#     x = re.sub(pattern, "CLINTON", x)     
#     pattern = re.compile(r'(\s|^)CHERY')
#     x = re.sub(pattern, "CHERRY", x) 
#     pattern = re.compile(r'(\s|^)CHRYSTEE|(\s|^)CHRYSTAL|(\s|^)CHTYSTIE|(\s|^)CHRYSTEL')
#     x = re.sub(pattern, "CHRYSTIE", x)     
#     pattern = re.compile(r'(\s|^)CARRAL|(\s|^)COYAL')
#     x = re.sub(pattern, "CANAL", x)    
#     pattern = re.compile(r'(\s|^)COLUMBIN')
#     x = re.sub(pattern, "COLUMBIA", x) 
#     pattern = re.compile(r'(\s|^)CAMNON')
#     x = re.sub(pattern, "CANNON", x) 
#     pattern = re.compile(r'(\s|^)CROWH')
#     x = re.sub(pattern, "CROWN", x) 
    
#     pattern = re.compile(r'(\s|^)DEVAL')
#     x = re.sub(pattern, "DEVOE", x)
#     pattern = re.compile(r'(\s|^)DEBOUCHEL')
#     x = re.sub(pattern, "DEBEVOISE",x)
#     pattern = re.compile(r'(\s|^)DAFONT')
#     x = re.sub(pattern, "DUPONT", x)
#     pattern = re.compile(r'(\s|^)DEGRAN')
#     x = re.sub(pattern, "DEGRAW", x)
#     pattern = re.compile(r'(\s|^)DENBO|(\s|^)DEKALB')
#     x = re.sub(pattern, "DE KALB", x)
#     pattern = re.compile(r'(\s|^)DELAMERE|(\s|^)DALANEY|(\s|^)DELANEY|(\s|^)DELANCY')
#     x = re.sub(pattern, "DELANCEY", x) 
    
#     pattern = re.compile(r'(\s|^)ELTHZROTH|(\s|^)ELLSWICK')
#     x = re.sub(pattern, "ELLIOTT", x)
#     pattern = re.compile(r'(\s|^)ELDREDGE|(\s|^)CLARIDGE')
#     x = re.sub(pattern, "ELDRIDGE", x) 
#     pattern = re.compile(r'(\s|^)ESSEY')
#     x = re.sub(pattern, "ESSEX", x) 
    
#     pattern = re.compile(r'(\s|^)FORSYTHE')
#     x = re.sub(pattern, "FORSYTH", x) 
#     pattern = re.compile(r'(\s|^)FLATHISH')
#     x = re.sub(pattern, "FLATBUSH", x)

#     pattern = re.compile(r'(\s|^)GLANCE')
#     x = re.sub(pattern, "GRAND", x) 
#     pattern = re.compile(r'(\s|^)GOAST')
#     x = re.sub(pattern, "GOERCK", x)
#     pattern = re.compile(r'(\s|^)GREENS')
#     x = re.sub(pattern, "GREENE", x)
#     pattern = re.compile(r'(\s|^)GREENRICH|(\s|^)GAMWICH')
#     x = re.sub(pattern, "GREENWICH", x) 

#     pattern = re.compile(r'(\s|^)HOUTON')
#     x = re.sub(pattern,  "HOUSTON", x) 
#     pattern = re.compile(r'(\s|^)HAVES')
#     x = re.sub(pattern, "HEWES", x) 
#     pattern = re.compile(r'(\s|^)HAKEY')
#     x = re.sub(pattern, "HALSEY", x)
#     pattern = re.compile(r'(\s|^)HEWEY')
#     x = re.sub(pattern, "HENRY", x)
#     pattern = re.compile(r'(\s|^)HICK')
#     x = re.sub(pattern, "HICKS", x)
#     pattern = re.compile(r'(\s|^)HUMBOLOT|(\s|^)HUMBARD|(\s|^)HUMBOLT')
#     x = re.sub(pattern, "HUMBOLDT", x) 
    
#     pattern = re.compile(r'(\s|^)JOHOM')
#     x = re.sub(pattern, "JOHNS", x) 
    
#     pattern = re.compile(r'(\s|^)KIOP|(\s|^)HEAP')
#     x = re.sub(pattern, "KEAP", x) 

#     pattern = re.compile(r'(\s|^)(LAY FAY ESTE)|(\s|^)LADORATT|(\s|^)LAFYAYETTE')
#     x = re.sub(pattern, "LAFAYETTE", x)
#     pattern = re.compile(r'(\s|^)LIRA|(\s|^)LOUMOR|(\s|^)LARMER')
#     x = re.sub(pattern, "LORIMER", x)
#     pattern = re.compile(r'(\s|^)LAAVIUK')
#     x = re.sub(pattern, "LAWRENCE", x) 
#     pattern = re.compile(r'(\s|^)LAIDLOW')
#     x = re.sub(pattern, "LUDLOW", x) 
#     pattern = re.compile(r'(\s|^)TEX|LEX(?=\s)') # perl = True
#     x = re.sub(pattern, "LEXINGTON", x)   
#     pattern = re.compile(r'(\s|^)REPPERTS')
#     x = re.sub(pattern, "LEFFERTS", x)

#     pattern = re.compile(r'(\s|^)PARLE|(\s|^)MALLE|(\s|^)MYETTE')
#     x = re.sub(pattern, "MYRTLE", x)
#     pattern = re.compile(r'(\s|^)(MC DOUGALL)|(\s|^)(MC DOUGAL)|(\s|^)(MCDOUGALL)')
#     x = re.sub(pattern, "MCDOUGAL", x)
#     pattern = re.compile(r'(\s|^)(MC DONOUGH)')
#     x = re.sub(pattern, "MCDONOUGH", x)
#     pattern = re.compile(r'(\s|^)MANZA|(\s|^)MAREY')
#     x = re.sub(pattern, "MARCY", x)
#     pattern = re.compile(r'(\s|^)MESCOLE')
#     x = re.sub(pattern, "MESEROLE", x)
#     pattern = re.compile(r'(\s|^)MEASE')
#     x = re.sub(pattern, "MOORE", x)
#     pattern = re.compile(r'(\s|^)MEDDLER')
#     x = re.sub(pattern, "MIDDLETON", x)
#     pattern = re.compile(r'(\s|^)MANGEN')
#     x = re.sub(pattern, "MANGIN", x)
#     pattern = re.compile(r'(\s|^)HAULL|(\s|^)MALLERY')
#     x = re.sub(pattern, "MULBERRY", x)

#     pattern = re.compile(r'(\s|^)NAPOLK')
#     x = re.sub(pattern, "NORFOLK", x)
#     pattern = re.compile(r'(\s|^)(VAST AND)')
#     x = re.sub(pattern, "NOSTRAND", x)

#     pattern = re.compile(r'(\s|^)DAK')
#     x = re.sub(pattern, "OAK", x)
#     pattern = re.compile(r'(\s|^)OLWEN')
#     x = re.sub(pattern, "OLIVER", x)
#     pattern = re.compile(r'(\s|^)GERHARD')
#     x = re.sub(pattern, "ORCHARD", x)

#     pattern = re.compile(r'(\s|^)PUTT')
#     x = re.sub(pattern, "PITT", x)
#     pattern = re.compile(r'(\s|^)PERROTT|(\s|^)(PERROTT PREMPONT)')
#     x = re.sub(pattern, "PIERREPONT", x)
#     pattern = re.compile(r'(\s|^)PLAD')
#     x = re.sub(pattern, "PLACE", x)
#     pattern = re.compile(r'(\s|^)PRUFER')
#     x = re.sub(pattern, "PROSPECT", x)
#     pattern = re.compile(r'(\s|^)PREDIDUNT')
#     x = re.sub(pattern, "PRESIDENT", x)
#     pattern = re.compile(r'(\s|^)PALOKA')
#     x = re.sub(pattern, "PULASKI", x)

#     pattern = re.compile(r'(\s|^)RUTHIE')
#     x = re.sub(pattern, "RUTLEDGE", x)
#     pattern = re.compile(r'(\s|^)RIDAL')
#     x = re.sub(pattern, "RIDGE", x)
#     pattern = re.compile(r'(\s|^)RAYSON')
#     x = re.sub(pattern, "RYERSON", x)
#     pattern = re.compile(r'(\s|^)REVENTON')
#     x = re.sub(pattern, "RIVINGTON", x)
#     pattern = re.compile(r'(\s|^)RUALMAINE|(\s|^)(RICER SIDE)')
#     x = re.sub(pattern, "RIVERSIDE", x)
#     pattern = re.compile(r'(\s|^)REDERICK|(\s|^)RENNICK')
#     x = re.sub(pattern, "RENWICK", x)

#     pattern = re.compile(r'(\s|^)SELLTOWN')
#     x = re.sub(pattern, "SULLIVAN", x)
#     pattern = re.compile(r'(\s|^)SISH')
#     x = re.sub(pattern, "SIDE", x)
#     pattern = re.compile(r'(\s|^)STUCKER')
#     x = re.sub(pattern, "STEUBEN", x)
#     pattern = re.compile(r'(\s|^)STATES')
#     x = re.sub(pattern, "STATE", x)
#     pattern = re.compile(r'(\s|^)SCHAALS')
#     x = re.sub(pattern, "SCHOLES", x)
#     pattern = re.compile(r'(\s|^)SUMME')
#     x = re.sub(pattern, "SUMMIT", x)
#     pattern = re.compile(r'(\s|^)SCHOMERDOSA')
#     x = re.sub(pattern, "SCHERMERHORN", x)
#     pattern = re.compile(r'(\s|^)DOUTH|(\s|^)SONSE')
#     x = re.sub(pattern, "SOUTH", x)
#     pattern = re.compile(r'(\s|^)STUYVESTANT')
#     x = re.sub(pattern, "STUYVESANT", x)

#     pattern = re.compile(r'(\s|^)STONPSON')
#     x = re.sub(pattern, "THOMPSON", x)
#     pattern = re.compile(r'(\s|^)TRAY')
#     x = re.sub(pattern, "TROY", x)
#     pattern = re.compile(r'(\s|^)TAYLER')
#     x = re.sub(pattern, "TAYLOR", x)

#     pattern = re.compile(r'(\s|^)WMON')
#     x = re.sub(pattern, "UNION", x)

#     pattern = re.compile(r'(\s|^)(WAR CAREN)')
#     x = re.sub(pattern, "VAN BUREN", x)
#     pattern = re.compile(r'(\s|^)VEMON')
#     x = re.sub(pattern, "VERNON", x)
#     pattern = re.compile(r'(\s|^)VANDERLY|(\s|^)VANDERSLIDE')
#     x = re.sub(pattern, "VANDERBILT", x)

#     pattern = re.compile(r'(\s|^)WYONIA')
#     x = re.sub(pattern, "WYONA", x)
#     pattern = re.compile(r'(\s|^)WITKINS')
#     x = re.sub(pattern, "WATKINS", x)
#     pattern = re.compile(r'(\s|^)WALLWORTH')
#     x = re.sub(pattern, "WALWORTH", x)
#     pattern = re.compile(r'(\s|^)WHIPPER')
#     x = re.sub(pattern, "WHIPPLE", x)
#     pattern = re.compile(r'(\s|^)WALLABANK|(\s|^)WALKABOUT')
#     x = re.sub(pattern, "WALLABOUT", x)
#     pattern = re.compile(r'\sWASH\s|(\s|^)WASTEWATER\s')
#     x = re.sub(pattern, "WASHINGTON", x) 

# #     pattern = re.compile(r"(\d)ST|ND|RD|TH\b")
# #     x = re.sub(pattern, "", x)

#     pattern = re.compile(r'\s&\s')
#     x = re.sub(pattern, "", x)

#     return x

# %%
# clean function check

def clean(x):
    # change the format to all upper
    x = str(x.upper())
    
#     pattern = re.compile(r'\sSTREET$|STREET|\sSTR$|\sSTE$|\sSRT$|\sSR$\s|SRT$|\sSST$|\sSEET|\sTREET|\sSHEER|\sSHEE|\sSTREE.|\sSREET|\sREET|\sSTEE|\sST')
#     x = re.sub(pattern, " ST", x)
    pattern = re.compile(r'\sSTREET\b|\bSTREET|\sSTR$|\sSTE$|\sSRT$|\sSR$\s|SRT$|\sSST$|\sSEET|\sTREET|\sSHEER|\sSHEE|\sSTREE\b|\sSREET|\sREET|\sSTEE|\sST')
    x = re.sub(pattern, " ST", x)

    # The orientations in the addresses
    pattern = re.compile(r'\sN\s')
    re.sub(pattern, " N ", x)
    pattern = re.compile(r'\sS\s')
    re.sub(pattern, " S ", x)
    pattern = re.compile(r'\sE\s')
    re.sub(pattern, " E ", x)
    pattern = re.compile(r'\sW\s')
    re.sub(pattern, " W ", x)
    
    # deal with the end of the addresses
    pattern = re.compile(r'\sDRIVE$|\sDR$|\sDV$|\sDE$|\sDRV$|\sDRI$|\sDRIV$|\sDRIE$')
    x = re.sub(pattern, " DR", x)
    pattern = re.compile(r'\sCIRCLE|\sCIR|\sCRL|\sCIRC|\sCR|\sCL|\sCIRCL|\sCICLE')
    x = re.sub(pattern, " CIR", x)
    pattern = re.compile(r'(\s|^)AVENUE|(\s|^)AVE|(\s|^)AV|(\s|^)AVN|(\s|^)AVEN|(\s|^)AVENU')
    x = re.sub(pattern, " AVE", x)
    pattern = re.compile(r"(?<=\s)COURT|CT|CRT|CRT|CTR|(?<=\s)COUR|(?<=\s)COT|(?<=\s)CORT")
    x = re.sub(pattern, " CT", x)
#     pattern = re.compile(r"\sBOULEVARD|\sBLVD|\sBVLD|\sBV|\sBLD|\sBD|\sBL|\sBLV")
#     x = re.sub(pattern, " BLVD", x)
    pattern = re.compile(r"\sBOULEVARD|\sBVLD|\sBV|\sBLD$|\sBD|\sBL$|\sBLV$")
    x = re.sub(pattern, " BLVD", x)
    pattern = re.compile(r"\sROAD|\sRD|\sRAD|\sROD")
    x = re.sub(pattern, " RD", x)
    pattern = re.compile(r"\sALLEY|\sALY|\sAL|\sALLY|\sALEY|\sALLE|\sAY")
    x = re.sub(pattern, " ALY", x)
    pattern = re.compile(r"\sPLACE|\sPL|\sPLC|\sPLE|\sPC|\sPLAC|\sPLCE|\sPCE")
    x = re.sub(pattern, " PL", x)
    pattern = re.compile(r"\sPK|\sPRK|\sPRAK|\sPAK")
    x = re.sub(pattern, " PARK", x)
    pattern = re.compile(r"\sPARKWAY|\sPKWY|\sPARKW|\sPWY|\sPKW|\sPRKWY|\sPKWY|\sPKW")
    x = re.sub(pattern, " PKWY", x)
    pattern = re.compile(r"\sAPPR|\sAPR|\sAPPROA|\sAPRCH|\sAPPRCH")
    x = re.sub(pattern, " APPROACH", x)
    pattern = re.compile(r"\sTERRACE|\sTER|\sTERR|\sTRC|\sTRCE|\sTR")
    x = re.sub(pattern, " TER", x)
    pattern = re.compile(r"\sPLAZA|\sPLZ|\sPLAZ|\sPZ|\sPLZA")
    x = re.sub(pattern, " PLZ", x)
    pattern = re.compile(r"\sLANE|\sLN|\sLNE|\sLAN")
    x = re.sub(pattern, " LN", x)
#     pattern = re.compile(r"\sBRIDGE|\sBRG|\sBRGD|\sBGE")
#     x = re.sub(pattern, " BRG",x)
    pattern = re.compile(r"\sHILL|\sHL|\sHLL|\sHIL")
    x = re.sub(pattern, " HL", x)
    pattern = re.compile(r"\sHEIGHTS|\sHTS|\sHT|\sHEIGHT|\sHEGHTS|\sHHT|\sHEIGT") 
    x = re.sub(pattern, " HTS", x)
    pattern = re.compile(r"\sSLP|\sSLEP|\sSLIIP|\sSLI")
    x = re.sub(pattern, " SLIP", x)
    pattern = re.compile(r"\sRON|\sRW|\sROE|\sROOW")
    x = re.sub(pattern, " ROW", x)
    pattern = re.compile(r"\sSQUARE") 
    x = re.sub(pattern, " SQ", x)
    

#     x<-gsub(".*\\((.*)\\).*", "\\1", x)
#     x<-gsub("(?<=\\s)(ST)","",x, perl = TRUE) #remove ST after space
#     x<-gsub("\\d+\\ - *\\d*|\\d+\\ TO *\\d*|\\d+\\-\\d*","",x) #remove addresses
    
#     pattern = re.compile(r".*\s(.*)\s.*")
#     x = re.sub(pattern, r"\1", x)
    pattern = re.compile(r"\sST$") # perl = true
    x = re.sub(pattern, "", x)# remove ST after space
#     pattern = re.compile(r"\d+\s") 
#     x = re.sub(pattern, "", x) # remove addresses
    
    # deal with special characters (\;';*'.')
    pattern = re.compile(r"\s(TO)\s") 
    x = re.sub(pattern, "-", x)
    pattern = re.compile(r"-") 
    x = re.sub(pattern, " ", x)
    pattern = re.compile(r"&") 
    x = re.sub(pattern, "AND", x)
    pattern = re.compile(r"[^\w\s]") 
    x = re.sub(pattern, "", x)  
    
    # dealing with numbered streets
    pattern = re.compile(r"(?<=[0-9])(ST|ND|RD|TH)")
    x = re.sub(pattern, "", x)
    pattern = re.compile(r"(\d+)(ST|ND|RD|TH)\b")
    x = re.sub(pattern, r"\1", x)
    pattern = re.compile(r"(\d+)(ST|ND|RD|TH)")
    x = re.sub(pattern, r"\1", x)
    pattern = re.compile(r"\sELEVENTH\s") 
    x = re.sub(pattern, "11", x)
    pattern = re.compile(r"\sTWELFTH\s") 
    x = re.sub(pattern, "12", x)    
    pattern = re.compile(r"\sTHIRTEENTH\s") 
    x = re.sub(pattern, "13", x)     
    pattern = re.compile(r"\sFORTEENTH\s|\sFOURTHENTH\s") 
    x = re.sub(pattern, "14", x)    
    pattern = re.compile(r"\sFIFTEENTH\s") 
    x = re.sub(pattern, "15", x)
    pattern = re.compile(r"\sSIXTEENTH\s") 
    x = re.sub(pattern, "16", x)
    pattern = re.compile(r"\sSEVENTEENTH\s") 
    x = re.sub(pattern, "17", x)
    pattern = re.compile(r"\sEIGHTEENTH\s") 
    x = re.sub(pattern, "18", x)
    pattern = re.compile(r"\sNINETEENTH\s") 
    x = re.sub(pattern, "19", x)
    pattern = re.compile(r"\sTWENTIETH\s|\sTWENTIEFTH\s") 
    x = re.sub(pattern, "20", x)
    pattern = re.compile(r"\sTHIRTIETH\s|\sTHIRTIEFTH\s") 
    x = re.sub(pattern, "30", x)
    pattern = re.compile(r"\sFORTIETH\s|\sFOURTIETH\s|\sFOURTHENTH\s") 
    x = re.sub(pattern, "40", x)
    pattern = re.compile(r"\sFIFTIETH\s") 
    x = re.sub(pattern, "50", x)
    pattern = re.compile(r"\sSIXTIETH\s") 
    x = re.sub(pattern, "60", x)
    pattern = re.compile(r"\sSEVENTIETH\s") 
    x = re.sub(pattern, "70", x)    
    pattern = re.compile(r"\sEIGHTIETH\s|\sEIGHTETH\s") 
    x = re.sub(pattern, "80", x) 
    pattern = re.compile(r"\sNINETIETH\s|\sNINTIETH\s") 
    x = re.sub(pattern, "90", x) 
    pattern = re.compile(r"\sFRIST\s|\sFRST\s|\sFIRST\s|\sONE\s|\sONE HUNDRED\s|\sONEHUNDRED\s|\sHUNDRED\s|\sHUDRED\s|\sHUNDED\s") 
    x = re.sub(pattern, "1", x) 
    pattern = re.compile(r"\sTWO HUNDRED\s|\sTWOHUNDRED\s|\sTWENTY\s|\sTWENTI\s|\sTENTI\s|\sSECOND\s|\sSECORD\s|\sSCOND\s|\sTWO\s") 
    x = re.sub(pattern, "2", x)
    pattern = re.compile(r"\sTHIRTY\s|\sTHIRTHY\s|\sTHIRTEY\s|\sTIRTY\s|\sTRITHY\s|\sTHRID\s|\sTHIRD\s|\sTIRD\s|\sTRIH\s|\sTHREE\s") 
    x = re.sub(pattern, "3", x)    
    pattern = re.compile(r"\sFORTY\s|\sFORTH\s|\sFOURTHY\s|\sFOURT\s|\sFRTY\s|\sFROTH\s|\sFROUTH\s|\sFOUR\s") 
    x = re.sub(pattern, "4", x)
    pattern = re.compile(r"\sFIFTY\s|\sFIFTHE\s|\sFIFTHY\s|\sFIFTH\s|\sFIFTEY\s|\sFIFT\s|\sFITY\s|\sFIFETH\s|\sFIFFTH\s|\sFIVE\s") 
    x = re.sub(pattern, "5", x)
    pattern = re.compile(r"\sSIXTY\s|\sSXTY\s|\sSIXY\s|\sSIXTHY\s|\sSIXTEY\s|\sSIXTH\s|\sSXTH\s|\sSITH\s|\sSIHXT\s|\sSIX\s") 
    x = re.sub(pattern, "6", x)
    pattern = re.compile(r"\sSEVENTEY\s|\sSVENTY\s|\sSEVENTI\s|\sSEVENTH\s|\sSEVENTY\s|\sSVEN\s|\sSVENTH\s|\sSEVENH\s|\sSEVENT\s|\sSEVEN\s") 
    x = re.sub(pattern, "7", x) 
    pattern = re.compile(r"\sEIGHTY\s|\sEIGHTEH\s|\sEIGHTEY\s|\sEIGHTE\s|\sEIGHTH\s|\sEITH\s|\sEIGHT\s|\sEIGHTTH\s|\sEIGTH\s|\sFIGHT\s") 
    x = re.sub(pattern, "8", x)       
    pattern = re.compile(r"\sUNITY\s|\sNINETY\s|\sNINETEY\s|\sNINETIETH\s|\sNINTH\s|\sNINTY\s") 
    x = re.sub(pattern, "9", x) 
    pattern = re.compile(r"\sTENTH\s") 
    x = re.sub(pattern, "10", x) 
#     pattern = re.compile(r"(?<=\d)(?=\d)") # postive look-behind assertion & positive look-ahead assertion
#     x = re.sub(pattern, "", x) 
    pattern = re.compile(r'^\bST\b')
    x = re.sub(pattern, "SAINT", x)
#     pattern = re.compile(r'\bHOUSE\b|\bHOSTEL\b|HOTEL|\bLODGE\b|\bLODGING\b')
#     x = re.sub(pattern,"", x)
    pattern = re.compile(r'\sHOUSE|\sHOSTEL|\sHOTEL|\sLODGE|\sLODGING')
    x = re.sub(pattern,"", x)

    # overall spacing problem extra white space
    pattern = re.compile(r'((\w+|\d+)\s\s(\w+|\d+))|((\w+|\d+)\s\s\s(\w+|\d+))')
    x = re.sub(pattern, r"\1 \2", x)

# x <- gsub("((\\w+|\\d+)\\s\\s(\\w+|\\d+))", "\\2 \\3", x)
# x <- gsub("((\\w+|\\d+)\\s\\s\\s(\\w+|\\d+))", "\\2 \\3", x)
    
    # change the order of the address, e.g: 4 W to W 4 & AVE after A-Z and Digits
    pattern = re.compile(r'(\w+|\d+)\s(\bN\b|\bW\b|\bS\b|\bE\b)')
    x = re.sub(pattern, r'\2 \1', x)
#     pattern = re.compile(r'(AVE)\s\d|(AVE)\s[A-Z])')
#     x = re.sub(pattern, r'\2 \1', x) 
#     pattern = re.compile(r'(AVE)\s(\d+\sTO\s\d+)')
#     x = re.sub(pattern, r'\2 \1', x) 
    pattern = re.compile(r'(AVE)\s(\d+)\s(\d+)')
    x = re.sub(pattern, r'\2-\3 \1', x) 
    pattern = re.compile(r'(AVE)\s([A-Z])')
    x = re.sub(pattern, r'\2 \1', x) 
#     pattern = re.compile(r'(AVE)\s(\b[A-Z])')
#     x = re.sub(pattern, r'\2 \1', x) 

    ###### ALL MANUAL CLEANING GOES BELOW HERE ######
    # Manual Cleaning
    pattern = re.compile(r'(\s|^)ALLANTIC|(\s|^)ATLASTA')
    x = re.sub(pattern, "ATLANTIC", x)
    pattern = re.compile(r'(\s|^)ALLEM')
    x = re.sub(pattern, "ALLEN", x)    
#     pattern = re.compile(r'(\s|^)ANENUE')
#     x = re.sub(pattern, "AVE", x)    
    pattern = re.compile(r'(\s|^)CROTON|(\s|^)GROTON')
    x = re.sub(pattern, "AUDUBON", x)    
    pattern = re.compile(r'(\s|^)(AT RINS)')
    x = re.sub(pattern, "ATKINS", x)     
    
    pattern = re.compile(r'(\s|^)BATTIE')
    x = re.sub(pattern, "BALTIC", x)      
    pattern = re.compile(r'(\s|^)BARREE')
    x = re.sub(pattern, "BARROW", x)   
    pattern = re.compile(r'(\s|^)BESSHLEY')
    x = re.sub(pattern, "BURLING", x)       
    pattern = re.compile(r'(\s|^)BIRY|(\s|^)(B WAY)|(\s|^)BWAY|(\s|^)BRAKSWAY')
    x = re.sub(pattern, "BROADWAY", x)         
    pattern = re.compile(r'(\s|^)BUSTWICK')
    x = re.sub(pattern, "BUSHWICK", x) 
    pattern = re.compile(r'(\s|^)BUTTER')
    x = re.sub(pattern, "BUTLER", x) 
    pattern = re.compile(r'(\s|^)BREEVORT')
    x = re.sub(pattern, "BREVOORT", x) 
    pattern = re.compile(r'(\s|^)BRENNEL|\sBROOMES\s|\sBROOM|(\s|^)BRANNAS|(\s|^)BROWN')
    x = re.sub(pattern, "BROOME", x) 
    pattern = re.compile(r'(\s|^)BLACKER|(\s|^)BLENKER')
    x = re.sub(pattern, "BLEECKER", x) 
    
    pattern = re.compile(r'(\s|^)CLAIR')
    x = re.sub(pattern, "CLASSON", x) 
    pattern = re.compile(r'(\s|^)CLISTEN')
    x = re.sub(pattern, "CLINTON", x)     
    pattern = re.compile(r'(\s|^)CHERY')
    x = re.sub(pattern, "CHERRY", x) 
    pattern = re.compile(r'(\s|^)CHRYSTEE|(\s|^)CHRYSTAL|(\s|^)CHTYSTIE|(\s|^)CHRYSTEL')
    x = re.sub(pattern, "CHRYSTIE", x)     
    pattern = re.compile(r'(\s|^)CARRAL|(\s|^)COYAL')
    x = re.sub(pattern, "CANAL", x)    
    pattern = re.compile(r'(\s|^)COLUMBIN')
    x = re.sub(pattern, "COLUMBIA", x) 
    pattern = re.compile(r'(\s|^)CAMNON')
    x = re.sub(pattern, "CANNON", x) 
    pattern = re.compile(r'(\s|^)CROWH')
    x = re.sub(pattern, "CROWN", x) 
    
    pattern = re.compile(r'(\s|^)DEVAL')
    x = re.sub(pattern, "DEVOE", x)
    pattern = re.compile(r'(\s|^)DEBOUCHEL')
    x = re.sub(pattern, "DEBEVOISE",x)
    pattern = re.compile(r'(\s|^)DAFONT')
    x = re.sub(pattern, "DUPONT", x)
    pattern = re.compile(r'(\s|^)DEGRAN')
    x = re.sub(pattern, "DEGRAW", x)
    pattern = re.compile(r'(\s|^)DENBO|(\s|^)DEKALB')
    x = re.sub(pattern, "DE KALB", x)
    pattern = re.compile(r'(\s|^)DELAMERE|(\s|^)DALANEY|(\s|^)DELANEY|(\s|^)DELANCY')
    x = re.sub(pattern, "DELANCEY", x) 
    
    pattern = re.compile(r'(\s|^)ELTHZROTH|(\s|^)ELLSWICK')
    x = re.sub(pattern, "ELLIOTT", x)
    pattern = re.compile(r'(\s|^)ELDREDGE|(\s|^)CLARIDGE')
    x = re.sub(pattern, "ELDRIDGE", x) 
    pattern = re.compile(r'(\s|^)ESSEY')
    x = re.sub(pattern, "ESSEX", x) 
    
    pattern = re.compile(r'(\s|^)FORSYTHE')
    x = re.sub(pattern, "FORSYTH", x) 
    pattern = re.compile(r'(\s|^)FLATHISH')
    x = re.sub(pattern, "FLATBUSH", x)

    pattern = re.compile(r'(\s|^)GLANCE')
    x = re.sub(pattern, "GRAND", x) 
    pattern = re.compile(r'(\s|^)GOAST')
    x = re.sub(pattern, "GOERCK", x)
    pattern = re.compile(r'(\s|^)GREENS')
    x = re.sub(pattern, "GREENE", x)
    pattern = re.compile(r'(\s|^)GREENRICH|(\s|^)GAMWICH')
    x = re.sub(pattern, "GREENWICH", x) 

    pattern = re.compile(r'(\s|^)HOUTON')
    x = re.sub(pattern,  "HOUSTON", x) 
    pattern = re.compile(r'(\s|^)HAVES')
    x = re.sub(pattern, "HEWES", x) 
    pattern = re.compile(r'(\s|^)HAKEY')
    x = re.sub(pattern, "HALSEY", x)
    pattern = re.compile(r'(\s|^)HEWEY')
    x = re.sub(pattern, "HENRY", x)
    pattern = re.compile(r'(\s|^)HICK')
    x = re.sub(pattern, "HICKS", x)
    pattern = re.compile(r'(\s|^)HUMBOLOT|(\s|^)HUMBARD|(\s|^)HUMBOLT')
    x = re.sub(pattern, "HUMBOLDT", x) 
    
    pattern = re.compile(r'(\s|^)JOHOM')
    x = re.sub(pattern, "JOHNS", x) 
    
    pattern = re.compile(r'(\s|^)KIOP|(\s|^)HEAP')
    x = re.sub(pattern, "KEAP", x) 

    pattern = re.compile(r'(\s|^)(LAY FAY ESTE)|(\s|^)LADORATT|(\s|^)LAFYAYETTE')
    x = re.sub(pattern, "LAFAYETTE", x)
    pattern = re.compile(r'(\s|^)LIRA|(\s|^)LOUMOR|(\s|^)LARMER')
    x = re.sub(pattern, "LORIMER", x)
    pattern = re.compile(r'(\s|^)LAAVIUK')
    x = re.sub(pattern, "LAWRENCE", x) 
    pattern = re.compile(r'(\s|^)LAIDLOW')
    x = re.sub(pattern, "LUDLOW", x) 
    pattern = re.compile(r'(\s|^)TEX|LEX(?=\s)') # perl = True
    x = re.sub(pattern, "LEXINGTON", x)   
    pattern = re.compile(r'(\s|^)REPPERTS')
    x = re.sub(pattern, "LEFFERTS", x)

    pattern = re.compile(r'(\s|^)PARLE|(\s|^)MALLE|(\s|^)MYETTE')
    x = re.sub(pattern, "MYRTLE", x)
    pattern = re.compile(r'(\s|^)(MC DOUGALL)|(\s|^)(MC DOUGAL)|(\s|^)(MCDOUGALL)')
    x = re.sub(pattern, "MCDOUGAL", x)
    pattern = re.compile(r'(\s|^)(MC DONOUGH)')
    x = re.sub(pattern, "MCDONOUGH", x)
    pattern = re.compile(r'(\s|^)MANZA|(\s|^)MAREY')
    x = re.sub(pattern, "MARCY", x)
    pattern = re.compile(r'(\s|^)MESCOLE')
    x = re.sub(pattern, "MESEROLE", x)
    pattern = re.compile(r'(\s|^)MEASE')
    x = re.sub(pattern, "MOORE", x)
    pattern = re.compile(r'(\s|^)MEDDLER')
    x = re.sub(pattern, "MIDDLETON", x)
    pattern = re.compile(r'(\s|^)MANGEN')
    x = re.sub(pattern, "MANGIN", x)
    pattern = re.compile(r'(\s|^)HAULL|(\s|^)MALLERY')
    x = re.sub(pattern, "MULBERRY", x)

    pattern = re.compile(r'(\s|^)NAPOLK')
    x = re.sub(pattern, "NORFOLK", x)
    pattern = re.compile(r'(\s|^)(VAST AND)')
    x = re.sub(pattern, "NOSTRAND", x)

    pattern = re.compile(r'(\s|^)DAK')
    x = re.sub(pattern, "OAK", x)
    pattern = re.compile(r'(\s|^)OLWEN')
    x = re.sub(pattern, "OLIVER", x)
    pattern = re.compile(r'(\s|^)GERHARD')
    x = re.sub(pattern, "ORCHARD", x)

    pattern = re.compile(r'(\s|^)PUTT')
    x = re.sub(pattern, "PITT", x)
    pattern = re.compile(r'(\s|^)PERROTT|(\s|^)(PERROTT PREMPONT)')
    x = re.sub(pattern, "PIERREPONT", x)
    pattern = re.compile(r'(\s|^)PLAD')
    x = re.sub(pattern, "PLACE", x)
    pattern = re.compile(r'(\s|^)PRUFER')
    x = re.sub(pattern, "PROSPECT", x)
    pattern = re.compile(r'(\s|^)PREDIDUNT')
    x = re.sub(pattern, "PRESIDENT", x)
    pattern = re.compile(r'(\s|^)PALOKA')
    x = re.sub(pattern, "PULASKI", x)

    pattern = re.compile(r'(\s|^)RUTHIE')
    x = re.sub(pattern, "RUTLEDGE", x)
    pattern = re.compile(r'(\s|^)RIDAL')
    x = re.sub(pattern, "RIDGE", x)
    pattern = re.compile(r'(\s|^)RAYSON')
    x = re.sub(pattern, "RYERSON", x)
    pattern = re.compile(r'(\s|^)REVENTON')
    x = re.sub(pattern, "RIVINGTON", x)
    pattern = re.compile(r'(\s|^)RUALMAINE|(\s|^)(RICER SIDE)')
    x = re.sub(pattern, "RIVERSIDE", x)
    pattern = re.compile(r'(\s|^)REDERICK|(\s|^)RENNICK')
    x = re.sub(pattern, "RENWICK", x)

    pattern = re.compile(r'(\s|^)SELLTOWN')
    x = re.sub(pattern, "SULLIVAN", x)
    pattern = re.compile(r'(\s|^)SISH')
    x = re.sub(pattern, "SIDE", x)
    pattern = re.compile(r'(\s|^)STUCKER')
    x = re.sub(pattern, "STEUBEN", x)
    pattern = re.compile(r'(\s|^)STATES')
    x = re.sub(pattern, "STATE", x)
    pattern = re.compile(r'(\s|^)SCHAALS')
    x = re.sub(pattern, "SCHOLES", x)
    pattern = re.compile(r'(\s|^)SUMME')
    x = re.sub(pattern, "SUMMIT", x)
    pattern = re.compile(r'(\s|^)SCHOMERDOSA')
    x = re.sub(pattern, "SCHERMERHORN", x)
    pattern = re.compile(r'(\s|^)DOUTH|(\s|^)SONSE')
    x = re.sub(pattern, "SOUTH", x)
    pattern = re.compile(r'(\s|^)STUYVESTANT')
    x = re.sub(pattern, "STUYVESANT", x)

    pattern = re.compile(r'(\s|^)STONPSON')
    x = re.sub(pattern, "THOMPSON", x)
    pattern = re.compile(r'(\s|^)TRAY')
    x = re.sub(pattern, "TROY", x)
    pattern = re.compile(r'(\s|^)TAYLER')
    x = re.sub(pattern, "TAYLOR", x)

    pattern = re.compile(r'(\s|^)WMON')
    x = re.sub(pattern, "UNION", x)

    pattern = re.compile(r'(\s|^)(WAR CAREN)')
    x = re.sub(pattern, "VAN BUREN", x)
    pattern = re.compile(r'(\s|^)VEMON')
    x = re.sub(pattern, "VERNON", x)
    pattern = re.compile(r'(\s|^)VANDERLY|(\s|^)VANDERSLIDE')
    x = re.sub(pattern, "VANDERBILT", x)

    pattern = re.compile(r'(\s|^)WYONIA')
    x = re.sub(pattern, "WYONA", x)
    pattern = re.compile(r'(\s|^)WITKINS')
    x = re.sub(pattern, "WATKINS", x)
    pattern = re.compile(r'(\s|^)WALLWORTH')
    x = re.sub(pattern, "WALWORTH", x)
    pattern = re.compile(r'(\s|^)WHIPPER')
    x = re.sub(pattern, "WHIPPLE", x)
    pattern = re.compile(r'(\s|^)WALLABANK|(\s|^)WALKABOUT')
    x = re.sub(pattern, "WALLABOUT", x)
    pattern = re.compile(r'\sWASH\s|(\s|^)WASTEWATER\s')
    x = re.sub(pattern, "WASHINGTON", x) 

#     pattern = re.compile(r"(\d)ST|ND|RD|TH\b")
#     x = re.sub(pattern, "", x)

    pattern = re.compile(r'\s&\s')
    x = re.sub(pattern, "", x)

    return x

# %%
df = pd.read_csv('census_1910_mn_small.csv')

# %%
df.columns
# Out:
# Index(['Record type', 'Standardized township (string)', 'County 2',
#        'Enumeration district 2',
#        'Consistent historical data person identifier',
#        'Dwelling sequence number', 'Dwelling serial number',
#        'Dwelling serial number 2', 'Household sequence within dwelling',
#        'Household sequence within dwelling, 8 digit',
#        'Household serial number 2',
#        'Household serial number, before large group quarters were split up (100% datasets)',
#        'Individual sequence number',
#        'Large group quarters that was split up (100% datasets)', 'Line number',
#        'Line number 2', 'Microfilm page number',
#        'Number of families in household',
#        'Number of person records in household, before large group quarters were split up  (100% datasets)',
#        'House number', 'Street address 2'],
#       dtype='object')

# %%
# df['Street address 2'].dropna(inplace = True)

# %%
df['new'] = df['Street address 2'].apply(lambda x: clean(str(x)))
df.new
# Out:
# 0                  38
# 1            EAST 107
# 2                  81
# 3            EAST 117
# 4             WEST 62
#             ...
# 1995         WEST 158
# 1996             E 78
# 1997            8 AVE
# 1998    LEXINGTON AVE
# 1999         E 609 14
# Name: new, Length: 2000, dtype: object

# %%
df.to_csv('census_1910_mn_small_clean_Python.csv', index = False)
