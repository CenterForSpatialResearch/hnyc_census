# %%
#import the packages that needed
import pandas as pd
import numpy as np
import regex as re
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('census_1910_mn_small.csv')

# %%
df.columns
# Out:
# Index(['Record type', 'Standardized township (string)', 'County 2',
#        'Enumeration district 2',
#        'Consistent historical data person identifier',
#        'Dwelling sequence number', 'Dwelling serial number',
#        'Dwelling serial number 2', 'Household sequence within dwelling',
#        'Household sequence within dwelling, 8 digit',
#        'Household serial number 2',
#        'Household serial number, before large group quarters were split up (100% datasets)',
#        'Individual sequence number',
#        'Large group quarters that was split up (100% datasets)', 'Line number',
#        'Line number 2', 'Microfilm page number',
#        'Number of families in household',
#        'Number of person records in household, before large group quarters were split up  (100% datasets)',
#        'House number', 'Street address 2'],
#       dtype='object')

# %%
def street_type(x):
    pattern = re.compile(r'\sSTREET|\sSTR|\sSTE$|\sSRT$|\sSR$\s|\sSST$|\sSEET$|\sTREET$|\sSHEER$|\sSHEE$|\sSTREE$|\sSREET$|\sREET$|\sSTEE$|\sST$')
    x = re.sub(pattern, " ST", x)
    pattern = re.compile(r'\sDRIVE$|\sDRV$|\sDRI$|\sDRIV$|\sDRIE$|\sD.$')
    x = re.sub(pattern, " DR", x)
    pattern = re.compile(r'\sCIRCLE$|\sCIRCL$|\sCICLE$|\sCIRC$|\sCIR$|\sCRL$|\sC.$')
    x = re.sub(pattern, " CIR", x)
    pattern = re.compile(r'\sAVENUE$|\sAVENU$|\sAVEN$|\sAVE$|\sAVN$\sAV$')
    x = re.sub(pattern, " AVE", x)
    pattern = re.compile(r"\sCOURT$|\sCT$|\sCRT$|\sCTR$|\sCOUR$|<=\sCOT$|\sCORT$")
    x = re.sub(pattern, " CT", x)
    pattern = re.compile(r"\sBOULEVARD$|\sBVLD|\sBL.$|\sB.$")
    x = re.sub(pattern, " BLVD", x)
    pattern = re.compile(r"\sROAD$|\sRD$|\sRAD$|\sROD$")
    x = re.sub(pattern, " RD", x)
    pattern = re.compile(r"\sALLEY$|\sALY$|\sALEY$|\sALL.$|\sA.$")
    x = re.sub(pattern, " ALY", x)
    pattern = re.compile(r"\sPLACE$|\sPL.$|\sP.$|\sPLAC$|\sPLCE$|\sPCE$")
    x = re.sub(pattern, " PL", x)
    pattern = re.compile(r"\sPK$|\sPRK$|\sPRAK$|\sPAK$")
    x = re.sub(pattern, " PARK", x)
    pattern = re.compile(r"\sPARKWAY$|\sPKWY$|\sPARKW$|\sPWY$|\sPKW$|\sPRKWY$|\sPKW$")
    x = re.sub(pattern, " PKWY", x)
    pattern = re.compile(r"\sAPPROA$|\sAPRCH$|\sAPPRCH$|\sAPPR$|\sAPR$")
    x = re.sub(pattern, " APPROACH", x)
    pattern = re.compile(r"\sTERRACE$|\sTERR$|\sTER$|\sTRCE$|\sTRC$|\sTR$")
    x = re.sub(pattern, " TER", x)
    pattern = re.compile(r"\sPLAZA$|\sPLZA$|\sPLZ$|\sPLAZ$|\sPZ$")
    x = re.sub(pattern, " PLZ", x)
    pattern = re.compile(r"\sLANE$|\sLNE$|\sLN$|\sLAN$")
    x = re.sub(pattern, " LN", x)
    pattern = re.compile(r"\sBRIDGE$|\sBRGD$|\sBRG$|\sBGE$")
    x = re.sub(pattern, " BRG",x)
    pattern = re.compile(r"\sHILL$|\sHLL$|\sHL$|\sHIL$")
    x = re.sub(pattern, " HL", x)
    pattern = re.compile(r"\sHEIGHTS$|\sHTS$|\sHT$|\sHEGHTS$|\sHEIGHT$|\sHHT$|\sHEIGT$") 
    x = re.sub(pattern, " HTS", x)
    pattern = re.compile(r"\sSLP$|\sSLEP$|\sSLIIP$|\sSLI$")
    x = re.sub(pattern, " SLIP", x)
    pattern = re.compile(r"\sROOW$|\sRO.$|\sRW$")
    x = re.sub(pattern, " ROW", x)
    pattern = re.compile(r"\sSQUARE$") 
    x = re.sub(pattern, " SQ", x)

    return x

df['Street address 2'] = df['Street address 2'].apply(lambda x : street_type(x))

# %%
df['Street address 2']
# Out:
# 0               38 ST
# 1       EAST 107TH ST
# 2             81ST ST
# 3       EAST 117TH ST
# 4        WEST 62ND ST
#             ...
# 1995      WEST 158 ST
# 1996        E 78TH ST
# 1997          8TH AVE
# 1998    LEXINGTON AVE
# 1999    609 E 14TH ST
# Name: Street address 2, Length: 2000, dtype: object

# %%
pattern_street_type_clean = r'(?<=\s)ST$|(?<=\s)DR$|(?<=\s)CIR$|(?<=\s)AVE$|(?<=\s)CT$|(?<=\s)BLVD$|(?<=\s)ALY$|(?<=\s)PLZ$|(?<=\s)PARK$|(?<=\s)PKWY$|(?<=\s)APPROACH$|(?<=\s)TER$|(?<=\s)PL$|(?<=\s)LN$|(?<=\s)BRG$|(?<=\s)HL$|(?<=\s)HTS$|(?<=\s)SLIP$|(?<=\s)ROW$|(?<=\s)SQ$'

def search_street_type(x):
    result = re.findall(pattern_street_type_clean, x)
    return "".join(result)

df['street_type_clean'] = df['Street address 2'].apply(lambda x : search_street_type(x))

# %%
df['street_type_clean']
# Out:
# 0        ST
# 1        ST
# 2        ST
# 3        ST
# 4        ST
#        ...
# 1995     ST
# 1996     ST
# 1997    AVE
# 1998    AVE
# 1999     ST
# Name: street_type_clean, Length: 2000, dtype: object

# %%
def street_name_clean(x):
    pattern = re.compile(r'\sALLANTIC\s|\sATLASTA\s')
    x = re.sub(pattern, "ATLANTIC", x)
    pattern = re.compile(r'\sALLEM\s')
    x = re.sub(pattern, "ALLEN", x)    

    pattern = re.compile(r'\sCROTON\s|\sGROTON\s')
    x = re.sub(pattern, "AUDUBON", x)    
    pattern = re.compile(r'\s(AT RINS)\s')
    x = re.sub(pattern, "ATKINS", x)     

    pattern = re.compile(r'\sBATTIE\s')
    x = re.sub(pattern, "BALTIC", x)      
    pattern = re.compile(r'\sBARREE\s')
    x = re.sub(pattern, "BARROW", x)   
    pattern = re.compile(r'\sBESSHLEY\s')
    x = re.sub(pattern, "BURLING", x)       
    pattern = re.compile(r'\sBIRY\s|\s(B WAY)\s|\sBWAY\s|\sBRAKSWAY\s')
    x = re.sub(pattern, "BROADWAY", x)         
    pattern = re.compile(r'\sBUSTWICK\s')
    x = re.sub(pattern, "BUSHWICK", x) 
    pattern = re.compile(r'\sBUTTER\s')
    x = re.sub(pattern, "BUTLER", x) 
    pattern = re.compile(r'\sBREEVORT\s')
    x = re.sub(pattern, "BREVOORT", x) 
    pattern = re.compile(r'\sBRENNEL\s|\sBROOMES\s|\sBROOM\s|\sBRANNAS\s|\sBROWN\s')
    x = re.sub(pattern, "BROOME", x) 
    pattern = re.compile(r'\sBLACKER\s|\sBLENKER\s')
    x = re.sub(pattern, "BLEECKER", x) 

    pattern = re.compile(r'\sCLAIR\s')
    x = re.sub(pattern, "CLASSON", x) 
    pattern = re.compile(r'\sCLISTEN\s')
    x = re.sub(pattern, "CLINTON", x)     
    pattern = re.compile(r'\sCHERY\s')
    x = re.sub(pattern, "CHERRY", x) 
    pattern = re.compile(r'\sCHRYSTEE\s|\sCHRYSTAL\s|\sCHTYSTIE\s|\sCHRYSTEL\s')
    x = re.sub(pattern, "CHRYSTIE", x)     
    pattern = re.compile(r'\sCARRAL\s|\sCOYAL\s')
    x = re.sub(pattern, "CANAL", x)    
    pattern = re.compile(r'\sCOLUMBIN\s')
    x = re.sub(pattern, "COLUMBIA", x) 
    pattern = re.compile(r'\sCAMNON\s')
    x = re.sub(pattern, "CANNON", x) 
    pattern = re.compile(r'\sCROWH\s')
    x = re.sub(pattern, "CROWN", x) 

    pattern = re.compile(r'\sDEVAL\s')
    x = re.sub(pattern, "DEVOE", x)
    pattern = re.compile(r'\sDEBOUCHEL\s')
    x = re.sub(pattern, "DEBEVOISE",x)
    pattern = re.compile(r'\sDAFONT\s')
    x = re.sub(pattern, "DUPONT", x)
    pattern = re.compile(r'\sDEGRAN\s')
    x = re.sub(pattern, "DEGRAW", x)
    pattern = re.compile(r'\sDENBO\s|\sDEKALB\s')
    x = re.sub(pattern, "DE KALB", x)
    pattern = re.compile(r'\sDELAMERE\s|\sDALANEY\s|\sDELANEY\s|\sDELANCY\s')
    x = re.sub(pattern, "DELANCEY", x) 

    pattern = re.compile(r'\sELTHZROTH\s|\sELLSWICK\s')
    x = re.sub(pattern, "ELLIOTT", x)
    pattern = re.compile(r'\sELDREDGE\s|\sCLARIDGE\s')
    x = re.sub(pattern, "ELDRIDGE", x) 
    pattern = re.compile(r'\sESSEY\s')
    x = re.sub(pattern, "ESSEX", x) 

    pattern = re.compile(r'\sFORSYTHE\s')
    x = re.sub(pattern, "FORSYTH", x) 
    pattern = re.compile(r'\sFLATHISH\s')
    x = re.sub(pattern, "FLATBUSH", x)

    pattern = re.compile(r'\sGLANCE\s')
    x = re.sub(pattern, "GRAND", x) 
    pattern = re.compile(r'\sGOAST\s')
    x = re.sub(pattern, "GOERCK", x)
    pattern = re.compile(r'\sGREENS\s')
    x = re.sub(pattern, "GREENE", x)
    pattern = re.compile(r'\sGREENRICH\s|\sGAMWICH\s')
    x = re.sub(pattern, "GREENWICH", x) 

    pattern = re.compile(r'\sHOUTON\s')
    x = re.sub(pattern,  "HOUSTON", x) 
    pattern = re.compile(r'\sHAVES\s')
    x = re.sub(pattern, "HEWES", x) 
    pattern = re.compile(r'\sHAKEY\s')
    x = re.sub(pattern, "HALSEY", x)
    pattern = re.compile(r'\sHEWEY\s')
    x = re.sub(pattern, "HENRY", x)
    pattern = re.compile(r'\sHICK\s')
    x = re.sub(pattern, "HICKS", x)
    pattern = re.compile(r'\sHUMBOLOT\s|\sHUMBARD\s|\sHUMBOLT\s')
    x = re.sub(pattern, "HUMBOLDT", x) 

    pattern = re.compile(r'\sJOHOM\s')
    x = re.sub(pattern, "JOHNS", x) 

    pattern = re.compile(r'\sKIOP\s|\sHEAP\s')
    x = re.sub(pattern, "KEAP", x) 

    pattern = re.compile(r'\s(LAY FAY ESTE)\s|\sLADORATT\s|\sLAFYAYETTE\s')
    x = re.sub(pattern, "LAFAYETTE", x)
    pattern = re.compile(r'\sLIRA\s|\sLOUMOR\s|\sLARMER\s')
    x = re.sub(pattern, "LORIMER", x)
    pattern = re.compile(r'\sLAAVIUK\s')
    x = re.sub(pattern, "LAWRENCE", x) 
    pattern = re.compile(r'\sLAIDLOW\s')
    x = re.sub(pattern, "LUDLOW", x) 
    pattern = re.compile(r'\sTEX|LEX\s') # perl = True
    x = re.sub(pattern, "LEXINGTON", x)   
    pattern = re.compile(r'\sREPPERTS\s')
    x = re.sub(pattern, "LEFFERTS", x)

    pattern = re.compile(r'\sPARLE\s|\sMALLE\s|\sMYETTE\s')
    x = re.sub(pattern, "MYRTLE", x)
    pattern = re.compile(r'\s(MC DOUGALL)\s|\s(MC DOUGAL)\s|\sMCDOUGALL\s')
    x = re.sub(pattern, "MCDOUGAL", x)
    pattern = re.compile(r'\s(MC DONOUGH)\s')
    x = re.sub(pattern, "MCDONOUGH", x)
    pattern = re.compile(r'\sMANZA\s|\sMAREY\s')
    x = re.sub(pattern, "MARCY", x)
    pattern = re.compile(r'\sMESCOLE\s')
    x = re.sub(pattern, "MESEROLE", x)
    pattern = re.compile(r'\sMEASE\s')
    x = re.sub(pattern, "MOORE", x)
    pattern = re.compile(r'\sMEDDLER\s')
    x = re.sub(pattern, "MIDDLETON", x)
    pattern = re.compile(r'\sMANGEN\s')
    x = re.sub(pattern, "MANGIN", x)
    pattern = re.compile(r'\sHAULL\s|\sMALLERY\s')
    x = re.sub(pattern, "MULBERRY", x)

    pattern = re.compile(r'\sNAPOLK\s')
    x = re.sub(pattern, "NORFOLK", x)
    pattern = re.compile(r'\s(VAST AND)\s')
    x = re.sub(pattern, "NOSTRAND", x)

    pattern = re.compile(r'\sDAK\s')
    x = re.sub(pattern, "OAK", x)
    pattern = re.compile(r'\sOLWEN\s')
    x = re.sub(pattern, "OLIVER", x)
    pattern = re.compile(r'\sGERHARD\s')
    x = re.sub(pattern, "ORCHARD", x)

    pattern = re.compile(r'\sPUTT\s')
    x = re.sub(pattern, "PITT", x)
    pattern = re.compile(r'\sPERROTT\s|\s(PERROTT PREMPONT)\s')
    x = re.sub(pattern, "PIERREPONT", x)
    pattern = re.compile(r'\sPLAD\s')
    x = re.sub(pattern, "PLACE", x)
    pattern = re.compile(r'\sPRUFER\s')
    x = re.sub(pattern, "PROSPECT", x)
    pattern = re.compile(r'\sPREDIDUNT\s')
    x = re.sub(pattern, "PRESIDENT", x)
    pattern = re.compile(r'\sPALOKA\s')
    x = re.sub(pattern, "PULASKI", x)

    pattern = re.compile(r'\sRUTHIE\s')
    x = re.sub(pattern, "RUTLEDGE", x)
    pattern = re.compile(r'\sRIDAL\s')
    x = re.sub(pattern, "RIDGE", x)
    pattern = re.compile(r'\sRAYSON\s')
    x = re.sub(pattern, "RYERSON", x)
    pattern = re.compile(r'\sREVENTON\s')
    x = re.sub(pattern, "RIVINGTON", x)
    pattern = re.compile(r'\sRUALMAINE\s|\s(RICER SIDE)\s')
    x = re.sub(pattern, "RIVERSIDE", x)
    pattern = re.compile(r'\sREDERICK\s|\sRENNICK\s')
    x = re.sub(pattern, "RENWICK", x)

    pattern = re.compile(r'\sSELLTOWN\s')
    x = re.sub(pattern, "SULLIVAN", x)
    pattern = re.compile(r'\sSISH\s')
    x = re.sub(pattern, "SIDE", x)
    pattern = re.compile(r'\sSTUCKER\s')
    x = re.sub(pattern, "STEUBEN", x)
    pattern = re.compile(r'\sSTATES\s')
    x = re.sub(pattern, "STATE", x)
    pattern = re.compile(r'\sSCHAALS\s')
    x = re.sub(pattern, "SCHOLES", x)
    pattern = re.compile(r'\sSUMME\s')
    x = re.sub(pattern, "SUMMIT", x)
    pattern = re.compile(r'\sSCHOMERDOSA\s')
    x = re.sub(pattern, "SCHERMERHORN", x)
    pattern = re.compile(r'\sDOUTH\s|\sSONSE\s')
    x = re.sub(pattern, "SOUTH", x)
    pattern = re.compile(r'\sSTUYVESTANT\s')
    x = re.sub(pattern, "STUYVESANT", x)

    pattern = re.compile(r'\sSTONPSON\s')
    x = re.sub(pattern, "THOMPSON", x)
    pattern = re.compile(r'\sTRAY\s')
    x = re.sub(pattern, "TROY", x)
    pattern = re.compile(r'\sTAYLER\s')
    x = re.sub(pattern, "TAYLOR", x)

    pattern = re.compile(r'\sWMON\s')
    x = re.sub(pattern, "UNION", x)

    pattern = re.compile(r'\s(WAR CAREN)\s')
    x = re.sub(pattern, "VAN BUREN", x)
    pattern = re.compile(r'\sVEMON\s')
    x = re.sub(pattern, "VERNON", x)
    pattern = re.compile(r'\sVANDERLY\s|\sVANDERSLIDE\s')
    x = re.sub(pattern, "VANDERBILT", x)

    pattern = re.compile(r'\sWYONIA\s')
    x = re.sub(pattern, "WYONA", x)
    pattern = re.compile(r'\sWITKINS\s')
    x = re.sub(pattern, "WATKINS", x)
    pattern = re.compile(r'\sWALLWORTH\s')
    x = re.sub(pattern, "WALWORTH", x)
    pattern = re.compile(r'\sWHIPPER\s')
    x = re.sub(pattern, "WHIPPLE", x)
    pattern = re.compile(r'\sWALLABANK|\sWALKABOUT\s')
    x = re.sub(pattern, "WALLABOUT", x)
    pattern = re.compile(r'\sWASH\s|\sWASTEWATER\s')
    x = re.sub(pattern, "WASHINGTON", x) 

    return x

df['Street address 2'] = df['Street address 2'].apply(lambda x : street_name_clean(x))

# %%
pd.set_option('display.max_rows', None)
df['Street address 2']
# Out:
# 0                                  38 ST
# 1                          EAST 107TH ST
# 2                                81ST ST
# 3                          EAST 117TH ST
# 4                           WEST 62ND ST
# 5                           WEST 90TH ST
# 6                                    A A
# 7                            EAST 8TH ST
# 8                                13TH ST
# 9               AMSTERDAM AVE 190-195 ST
# 10                          WEST 78TH ST
# 11                             CHERRY ST
# 12                 CENTRAL PARK WEST AVE
# 13                          EAST 50TH ST
# 14                            WEST 26 ST
# 15                          WEST 61ST ST
# 16                            CORNICE ST
# 17                         AMSTERDAM AVE
# 18                            EAST 32 ST
# 19                              WEST 145
# 20                         WEST 117TH ST
# 21                         EAST FIFTH ST
# 22                                 84 ST
# 23                          WEST 43RD ST
# 24                         WEST 134TH ST
# 25                                   101
# 26                                  21ST
# 27                   WEST SIXTY FIFTH ST
# 28                                W17 ST
# 29                          E HOUSTON ST
# 30                           AUDUBON AVE
# 31                        NINTY FIRST ST
# 32                         AMSTERDAM AVE
# 33                 THIRD AVENUE (3D AVE)
# 34                       SIXTY SECOND ST
# 35                              AVENUE A
# 36                             HUDSON ST
# 37                           EAST 8TH ST
# 38                                112 ST
# 39                         EAST NINTH ST
# 40                           EAST 115 ST
# 41                           WEST 113 ST
# 42                         125TH ST WEST
# 43                            EAST 76 ST
# 44                          EAST END AVE
# 45                              PARGRAVE
# 46                       WEST HOUSTON ST
# 47                           MULBERRY ST
# 48                          EAST 66TH ST
# 49                          WEST 39TH ST
# 50                           CHRYSTAL ST
# 51                          WEST 38TH ST
# 52                         WEST 142ND ST
# 53                            MADISON ST
# 54                           WEST 144 ST
# 55                            CARMINE ST
# 56                               59TH ST
# 57                           WEST 116 ST
# 58                              E 123 ST
# 59                            RENDALL ST
# 60                         EAST 68 TH ST
# 61                            SECOND AVE
# 62                         EAST 125TH ST
# 63                            EAST 56 ST
# 64                            EAST 97 ST
# 65                          MANHATTAN ST
# 66                         EAST 90 TH ST
# 67                         EAST 104TH ST
# 68                             LINTON ST
# 69                            EIGHTH AVE
# 70                            SEVENTH ST
# 71                            WEST 94 ST
# 72                           WEST 135 ST
# 73                           WEST 140 ST
# 74                         EAST 68 TH ST
# 75                               MOTT ST
# 76                                134 ST
# 77                  EAST FIFTY FOURTH ST
# 78                            STANTON ST
# 79                         EAST 119TH ST
# 80                            WEST 89 ST
# 81                              W 135 ST
# 82                            EAST 76 ST
# 83                               7TH AVE
# 84                          EAST 32ND ST
# 85                               E 40 ST
# 86                              RIDGE ST
# 87                              SIXTH ST
# 88                         EAST 119TH ST
# 89                         EDGECOMBE AVE
# 90                            E 117TH ST
# 91                              SOUTH ST
# 92                           SEVENTH AVE
# 93                         WEST 111TH ST
# 94                          EAST 74TH ST
# 95                          GREENWICH ST
# 96           AMSTERDAM AVE 136 TO 138 ST
# 97                              110TH ST
# 98                            MATT ST PL
# 99                             ACHARD ST
# 100                          EAST 101 ST
# 101                          DOMENICK ST
# 102                         EAST 31ST ST
# 103                            LUDLOW ST
# 104                         EAST 99TH ST
# 105                         WEST 46TH ST
# 106                           WEST 49 ST
# 107                       FIFTY FIFTH ST
# 108        99TH ST BETWEEN CP WEST & CIR
# 109                         EAST MUTH ST
# 110                           EAST 16 ST
# 111                              W153 ST
# 112                          WEST 135 ST
# 113                          WEST 135 ST
# 114                           CANNINE ST
# 115                        EAST 127TH ST
# 116                          WEST 112 ST
# 117                 WEST THIRTY THIRD ST
# 118                          EAST 118 ST
# 119                     EAST SIXTIETH ST
# 120                         EAST 13TH ST
# 121                        EAST NINTH ST
# 122                             JAMES ST
# 123                          EAST 121 ST
# 124                        EAST 106TH ST
# 125                              22ND ST
# 126                           CLINTON ST
# 127                            FIRST AVE
# 128                         WEST 16TH ST
# 129                         EAST 81ST ST
# 130                        BRADHURST AVE
# 131                        EAST 90 TH ST
# 132                          MADISON AVE
# 133                             AVENUE A
# 134                         JEFFERSON ST
# 135                          DELANCEY ST
# 136                        LEXINGTON AVE
# 137                         COLUMBUS AVE
# 138                            W 26TH ST
# 139                           CLINTON ST
# 140                          EAST 129 ST
# 141                              1ST AVE
# 142                           EAST 87 ST
# 143                        WEST 118TH ST
# 144                               107 ST
# 145                         WEST 62ND ST
# 146                             PARK AVE
# 147                           WEST 39 ST
# 148                              26TH ST
# 149                          THOMPSON ST
# 150                           SEVENTH ST
# 151                         EAST 102D ST
# 152                        WEST 152ND ST
# 153                            FIFTH AVE
# 154                           EAST 64 ST
# 155                             DUANE ST
# 156                               123 ST
# 157                         EAST 78TH ST
# 158                           EAST 69 ST
# 159                             109TH ST
# 160                        WEST 131ST ST
# 161                        EAST SIXTH ST
# 162                           MULBERY ST
# 163                           SECOND AVE
# 164                         WEST 96TH ST
# 165                           FORSYTH ST
# 166                        WEST 179ST ST
# 167                           EAST 83 ST
# 168                            FIRST AVE
# 169                              9TH AVE
# 170                          EAST 3RD ST
# 171                              61ST ST
# 172                          WEST 129 ST
# 173                           SECOND AVE
# 174                        EAST 110TH ST
# 175                         WEST 62ND ST
# 176                        WEST 134TH ST
# 177                              7TH ALY
# 178                             BROADWAY
# 179                      SIXTY SECOND ST
# 180                          WEST 141 ST
# 181                         EAST 85TH ST
# 182                         EAST 56TH ST
# 183                              W116 ST
# 184                          WELL OAK ST
# 185                         EAST 16TH ST
# 186                         EAST 99TH ST
# 187                          ATTORNEY ST
# 188                        WEST 171ST ST
# 189                        LEXINGTON AVE
# 190                         ELIZABETH ST
# 191                         ELIZABETH ST
# 192                        WEST 115TH ST
# 193                           WEST 52 ST
# 194                        WEST 164TH ST
# 195                         WEST 22ND ST
# 196                         EAST 97TH ST
# 197                        AMSTERDAM AVE
# 198                          WEST 144 ST
# 199                              22ND ST
# 200                        ST NICOLAS PL
# 201               WASHINGTON SQUARE WEST
# 202                             HENRY ST
# 203                             JONES ST
# 204                          EAST 118 ST
# 205                              W146 ST
# 206                             HENRY ST
# 207                             LEWIS ST
# 208                             10TH AVE
# 209                           EIGHTH AVE
# 210                           WOOSTER ST
# 211                          EAST 32D ST
# 212                           EAST 56 ST
# 213                        AMSTERDAM AVE
# 214                        MANHATTAN AVE
# 215                         WEST 76TH ST
# 216                          WEST 101 ST
# 217                      TWENTY EIGHT ST
# 218                                52 ST
# 219                        AMSTERDAM AVE
# 220                         WEST 15TH ST
# 221                        EAST TENTH ST
# 222                      SIXTY SECOND ST
# 223                              W115 ST
# 224             ONE HUNDRED AND SEVEN ST
# 225                        LEXINGTON AVE
# 226                     APRIL 18 E 44 ST
# 227                             AVENUE B
# 228                              E 82 ST
# 229                        EAST 109TH ST
# 230                             E 111 ST
# 231                            MONROE ST
# 232                         EAST 26TH ST
# 233                            PRINCE ST
# 234                            FOURTH ST
# 235     EAST ONE HUNRED AND TWENTY NINTH
# 236                              W 10 ST
# 237                 WEST FOURTY NINTH ST
# 238                        EAST 86 TH ST
# 239                             GRAND ST
# 240                          ST MARKS PL
# 241                        EAST 112TH ST
# 242                            FIFTH AVE
# 243                           EIGHTH AVE
# 244                            BAXTER ST
# 245                         17ST ST EAST
# 246                        GRAMERCY PARK
# 247                          134 ST WEST
# 248                            SPRING ST
# 249                              55TH ST
# 250                         WEST 37TH ST
# 251                        127TH ST WEST
# 252                        WEST 120TH ST
# 253                               120 ST
# 254                                29 ST
# 255                              27TH ST
# 256                          WEST 140 ST
# 257                             AVENUE A
# 258                         WEST 15TH ST
# 259                           SECOND AVE
# 260                            PRINCE ST
# 261                        WEST 164TH ST
# 262                         ELIZABETH ST
# 263                            MONROE ST
# 264                         WEST 57TH ST
# 265                              W115 ST
# 266                         WEST 47TH ST
# 267                        WEST 137TH ST
# 268                            BROOME ST
# 269                           WEST 47 ST
# 270                              W139 ST
# 271                         ELIZABETH ST
# 272                         WEST HOUSTON
# 273                              W 83 ST
# 274                                84 ST
# 275                          EAST 199 ST
# 276                        EAST 102ND ST
# 277                               BOWERY
# 278                       EAST FOURTH ST
# 279                        LEXINGTON AVE
# 280                        EAST 114TH ST
# 281                               W 67TH
# 282                            LUDLOW ST
# 283                                E 117
# 284                            MONROE ST
# 285                              E 99 ST
# 286                         WEST 87TH ST
# 287                                 MOTT
# 288                         GRAMLICH AVE
# 289                           WEST 55 ST
# 290                          EAST 110 ST
# 291                           EAST 71 ST
# 292                         COLUMBUS AVE
# 293                               W 49TH
# 294                           SECOND AVE
# 295                        THIRTEENTH ST
# 296                         EAST 89TH ST
# 297                 TWENTY THIRD ST EAST
# 298                           WEST 50 ST
# 299                              83RD ST
# 300                        WEST 147TH ST
# 301                          THOMPSON ST
# 302                             10TH AVE
# 303                         EAST 81ST ST
# 304                                16 ST
# 305                        MANHATTAN AVE
# 306                             FIFTH ST
# 307                  WEST FIFTY THIRD ST
# 308                         EAST END AVE
# 309                          SEVENTH AVE
# 310                        WEST 178TH ST
# 311                            FIRST AVE
# 312                         WEST HOUSTON
# 313                        EAST 105TH ST
# 314                             E 108 ST
# 315                             WEST END
# 316                       SIXTY THIRD ST
# 317                             PARK AVE
# 318                 NINETY-THIRD (93) ST
# 319                         EAST 98TH ST
# 320                              8TH AVE
# 321                WEST SEVENTY THIRD ST
# 322                           NORFOLK ST
# 323                              E 83 ST
# 324                                51 ST
# 325                        WEST 185TH ST
# 326                        EAST THIRD ST
# 327                        WEST 106TH ST
# 328                        EAST 127TH ST
# 329                           W 184TH ST
# 330                        MANHATTAN AVE
# 331                         EAST 86TH ST
# 332                        100TH ST EAST
# 333                    MORNINGSIDE AVE E
# 334                           FORSYTH ST
# 335                           WEST 59 ST
# 336                          WEST 142 ST
# 337                             HENRY ST
# 338                            E 78TH ST
# 339                        WADSWORTH AVE
# 340                        WEST 105TH ST
# 341                            MONROE ST
# 342                             FIRST ST
# 343                              W145 ST
# 344                             NINTH ST
# 345                        AMSTERDAM AVE
# 346                           WEST 61 ST
# 347                               E 72RD
# 348                        WEST 159TH ST
# 349                                96 ST
# 350                              16TH ST
# 351     (MARTHA WASHINGTON HOTEL) EAST 2
# 352                           W 103RD ST
# 353                        EAST SIXTH ST
# 354                            E 79TH ST
# 355                     TWENTY EIGHTH ST
# 356         68 ST BETWEEN LEXINGTON & TH
# 357     WEST 131 ST SO SIDE OLD BROADWAY
# 358                         WEST 14TH ST
# 359                        WEST 121ST ST
# 360                          CHRYSTIE ST
# 361      WEST ONE HUNDRED SEVENTEENTH ST
# 362                              8TH AVE
# 363                                   88
# 364     EAST ONE HUNDRED AND THIRTY THIR
# 365                          CHRYSTIE ST
# 366                          HAMILTON ST
# 367                             ALLEN ST
# 368                          MULBERRY ST
# 369                         EAST 69TH ST
# 370                        126TH ST WEST
# 371                           SECOND AVE
# 372     SOUTH SIDE WEST EIGHTY EIGHTH ST
# 373                              WAIT 10
# 374                             119TH ST
# 375                            HESTOR ST
# 376                            THIRD AVE
# 377                            E HOUSTON
# 378                        EAST 104TH ST
# 379                           NORFOLK ST
# 380                          WEST 127 ST
# 381                              KING ST
# 382                              81ST ST
# 383                           BEDFORD ST
# 384                      SIXTY SECOND ST
# 385                              11TH ST
# 386                            DOVERS ST
# 387                        CITY HALL AVE
# 388                      THIRTY EIGHT ST
# 389                            LUDLOW ST
# 390                              PITT ST
# 391                                12 ST
# 392                        WEST 121ST ST
# 393                GRAMERCY PARK (NO 34)
# 394                         EAST 73RD ST
# 395                         ELIZABETH ST
# 396                         GOUVERNER ST
# 397                              49TH ST
# 398                             FIFTH ST
# 399                         EAST 67TH ST
# 400                        WEST 170TH ST
# 401                         EAST 99TH ST
# 402                        EAST TENTH ST
# 403                       WEST 151 ST ST
# 404                            CANNON ST
# 405                          WEST 103 ST
# 406                            GOERCK ST
# 407                        EAST 90 TH ST
# 408                              W137 ST
# 409                           WEST 70 ST
# 410                             BROADWAY
# 411                           CLINTON ST
# 412                           EIGHTH AVE
# 413                           SHERIFF ST
# 414                            THIRD ALY
# 415                         WEST 77TH ST
# 416                         WEST 29TH ST
# 417                           SECOND AVE
# 418                              W134 ST
# 419                          SEVENTH AVE
# 420                              PETT ST
# 421                             LEROY ST
# 422                           TWELFTH ST
# 423                      EIGHTY-NINTH ST
# 424                       EAST SECOND ST
# 425                         WEST 44TH ST
# 426                            BAXTER ST
# 427                  EAST NINTY NINTH ST
# 428                            THIRD AVE
# 429                               W77 ST
# 430                           W 127TH ST
# 431                           W 123RD ST
# 432                             BROADWAY
# 433                             W 112 ST
# 434                        WEST 118TH ST
# 435                         EAST 70TH ST
# 436                        WEST BROADWAY
# 437                              E 78 ST
# 438             EAST SEVENTH ST AVENUE B
# 439                            CORTLANDT
# 440                         WEST 46TH ST
# 441                 WEST THIRTY FIRST ST
# 442                               126 ST
# 443                           25 ST EAST
# 444                            BALTON RD
# 445                             SULLIVAN
# 446                                W 114
# 447                             ESSEX ST
# 448                            FIRST AVE
# 449                     EAST SIXTIETH ST
# 450                            E 12TH ST
# 451                           E 118TH ST
# 452                         COLUMBUS AVE
# 453                                61 ST
# 454                               108 ST
# 455                             PARK AVE
# 456         68 ST BETWEEN LEXINGTON & TH
# 457                         WEST 38TH ST
# 458                         WEST 10TH ST
# 459                         WEST 43RD ST
# 460                         EAST 58TH ST
# 461                              W145 ST
# 462                                60 ST
# 463                         EAST 23RD ST
# 464                             119TH ST
# 465                         EAST 35TH ST
# 466                                 EAST
# 467                              PITT ST
# 468                        WEST 112TH ST
# 469                        AMSTERDAM AVE
# 470                 EAST FIFTY-SECOND ST
# 471                        EAST 110TH ST
# 472                           NORFOLK ST
# 473                        EAST 101ST ST
# 474                          EAST 105 ST
# 475                             AVENUE B
# 476                          WEST 116 ST
# 477                            W 11TH ST
# 478                        EAST NINTH ST
# 479                               111 ST
# 480            LEXINGTON AVENUE WESTSIDE
# 481                         WEST 30TH ST
# 482                           MADISON ST
# 483                           EAST 80 ST
# 484                           SECOND AVE
# 485                               134 ST
# 486                          WEST 111 ST
# 487                          HERDENER ST
# 488                         WEST 26TH ST
# 489                          WEST 142 ST
# 490                              W135 ST
# 491                           EAST 52 ST
# 492                         E HOUSTON ST
# 493                             CORNELIA
# 494                              E 72 ST
# 495                    BLACKWELLS ISLAND
# 496                             GAARD ST
# 497                             EAST 112
# 498                            FIRST AVE
# 499                         EAST 19TH ST
# 500                        EAST NINTH ST
# 501                              8TH AVE
# 502                         WEST 57TH ST
# 503                         EAST 70TH ST
# 504                           SECOND AVE
# 505                        WEST 137TH ST
# 506                           WEST 58 ST
# 507                               118 ST
# 508                         EAST 12TH ST
# 509                         ELIZABETH ST
# 510                           SECOND AVE
# 511                        EAST 101ST ST
# 512                        WEST 146TH ST
# 513                              3RD AVE
# 514      100TH ST BETWEEN COLUMBUS AVE &
# 515                          EAST 104 ST
# 516                         EAST 87TH ST
# 517                            HESTER ST
# 518                             NINTH ST
# 519                         EAST 89TH ST
# 520                          THOMPSON ST
# 521                          ATTORNEY ST
# 522     RUTGERS PLACE (KNOWN AS MONROE S
# 523            RUTGERS PLACE (MONROE ST)
# 524                     EAST-33TH-STREET
# 525                             HENRY ST
# 526                        WEST 164TH ST
# 527                        WEST 142ND ST
# 528                              ELLO ST
# 529                          CLARKSON ST
# 530                    BLACKWELLS ISLAND
# 531                        LEXINGTON AVE
# 532                           EAST 48 ST
# 533                             AVENUE A
# 534                               BOWERY
# 535                              81ST ST
# 536                          SULLIVAN ST
# 537                           WEST 85 ST
# 538                          MULBERRY ST
# 539                             PEK SHIP
# 540                               10 AVE
# 541                         EAST 13TH ST
# 542                        EAST 106TH ST
# 543                        WEST 113TH ST
# 544          CATHARINE ST CATHARINE STEE
# 545                        SEVENTIETH ST
# 546                            SECOND ST
# 547                             AVENUE A
# 548                        WEST 116TH ST
# 549                                92 ST
# 550                         EAST 83RD ST
# 551                           SEVENTH ST
# 552                        EAST BROADWAY
# 553                    BLACKWELLS ISLAND
# 554                             WEST 143
# 555                          FORSYTHE ST
# 556               WEST THIRTY SEVENTH ST
# 557                            THIRD AVE
# 558                          ATTORNEY ST
# 559                         WEST 26TH ST
# 560                         EAST 29TH ST
# 561                        STUYVESANT ST
# 562                              8TH AVE
# 563                         WEST 29TH ST
# 564                              61ST ST
# 565                           WEST 27 ST
# 566                         WEST 46TH ST
# 567                           WEST 135TH
# 568                        AMSTERDAM AVE
# 569                       FIFTY FIFTH ST
# 570                          WEST 137 ST
# 571                        WEST 106TH ST
# 572                                 E 89
# 573                                E 118
# 574                                AVE A
# 575                             CANAL ST
# 576                            MONROE ST
# 577                            WILLET ST
# 578                         PLEASANT AVE
# 579                           SECOND AVE
# 580                          LEONORE AVE
# 581                SECOND AVENUE 2ND AVE
# 582                            WADSWORTH
# 583                           WEST 39 ST
# 584                         RIVINGTON ST
# 585                           EAST 87 ST
# 586                             THIRD ST
# 587                              33RD ST
# 588                           SECOND AVE
# 589                           EAST 52 ST
# 590                         ELIZABETH ST
# 591                        EAST 115TH ST
# 592                                W 122
# 593                         WEST 47TH ST
# 594                           EAST 96 ST
# 595                        WEST BROADWAY
# 596                         EAST 80TH ST
# 597                          WEST 136 ST
# 598                              52ND ST
# 599                        WEST 106TH ST
# 600                         EAST 76TH ST
# 601                              11TH ST
# 602                         WEST 35TH ST
# 603                              WEST 51
# 604                         WEST 30TH ST
# 605                         EAST 39TH ST
# 606                               W16 ST
# 607                             ESSEX ST
# 608                           WEST 52 ST
# 609                           WEST 39 ST
# 610                           CLINTON ST
# 611                            FIRST AVE
# 612                          SULLIVAN ST
# 613                               W 60TH
# 614                        WEST 146TH ST
# 615                         EAST 69TH ST
# 616                        WEST 106TH ST
# 617                         WEST 38TH ST
# 618                           JACKSON ST
# 619                         EAST 24TH ST
# 620                           AEXTTE AVE
# 621                            SECOND ST
# 622                        CLAREMONT AVE
# 623                         EAST 42ND ST
# 624                          EAST 104 ST
# 625                          WEST 158 ST
# 626                               121 ST
# 627                         ELIZABETH ST
# 628                              E 84 ST
# 629                              PITT ST
# 630                               158 ST
# 631                              BANK ST
# 632                           EAST 93 ST
# 633                             AVENUE D
# 634                             E 6TH ST
# 635                            NINTH AVE
# 636                             ESSEX ST
# 637                         COLUMBUS AVE
# 638                             LOUIS ST
# 639                          FORTIETH ST
# 640                             110TH ST
# 641                         EAST 50TH ST
# 642                              1ST AVE
# 643                               E31 ST
# 644                        WEST 164TH ST
# 645                          WEST 117 ST
# 646                             AVENUE D
# 647                           EAST 87 ST
# 648                              PITT ST
# 649                            E 86TH ST
# 650                              W 36 ST
# 651                         EAST 90TH ST
# 652                            NINTH AVE
# 653                               4TH ST
# 654                        AMSTERDAM AVE
# 655                           WEST 35 ST
# 656                              11TH ST
# 657                        EDGECOMBE AVE
# 658                              39TH ST
# 659                              2ND AVE
# 660                              PITT ST
# 661                               BOWERY
# 662                         WEST 57TH ST
# 663                           FORSYTH ST
# 664                          WEST 150 ST
# 665                          FORSYTHE ST
# 666                           EIGHTH AVE
# 667                            FIFTH AVE
# 668                              PIKE ST
# 669                        AMSTERDAM AVE
# 670                         EAST 57TH ST
# 671                             SIXTH ST
# 672                    CENTRAL PARK WEST
# 673             ONE HUNDRED AND SEVEN ST
# 674                    BLACKWELLS ISLAND
# 675                           EAST 83 ST
# 676                       FORTY FIRST ST
# 677                        EAST 117TH ST
# 678            ONE HUNDRED AND FOURTH ST
# 679                        EAST 104TH ST
# 680                           SECOND AVE
# 681                        WEST 118TH ST
# 682                            EIGTH AVE
# 683                         WEST 68TH ST
# 684                                91 ST
# 685                           SECOND AVE
# 686                           ORCHARD ST
# 687                           EAST 93 ST
# 688                         WEST 27TH ST
# 689                        EAST 114TH ST
# 690                              1ST AVE
# 691                              W 20 ST
# 692                         WEST 46TH ST
# 693                           WEST 40 ST
# 694                          EAST 117 ST
# 695                      EIGHTY-NINTH ST
# 696                           FORSYTH ST
# 697                         WEST 93RD ST
# 698                         WEST 30TH ST
# 699                          THOMPSON ST
# 700                        WEST 149TH ST
# 701                           E 87 TH ST
# 702                           EIGHTH AVE
# 703                            BAYARD ST
# 704                         EAST 34TH ST
# 705                               MANGIN
# 706                          WEST 141 ST
# 707                         EAST 39TH ST
# 708                              KING ST
# 709                        AMSTERDAM AVE
# 710                        WEST 132ND ST
# 711                             GAARD ST
# 712                  EAST NINTY SIXTH ST
# 713                             AVENUE A
# 714                          WEST 138 ST
# 715                         EAST 18TH ST
# 716                         EAST 87TH ST
# 717                         EAST 87TH ST
# 718                           HOUSTON ST
# 719     TOOT WEST 11TH STAT STEWER EEL V
# 720                       EAST SECOND ST
# 721                            W 44TH ST
# 722                          ELDRIDGE ST
# 723                          MADISON AVE
# 724                             E 121 ST
# 725                           SECOND AVE
# 726                         EAST 16TH ST
# 727                           MADISON ST
# 728                        EAST 90 TH ST
# 729                            WEST 59TH
# 730                            NINTH AVE
# 731                          SEVENTH AVE
# 732                            EAST 33RD
# 733                         COLUMBUS AVE
# 734                    CENTRAL PARK WEST
# 735                          MULBERRY ST
# 736                               BOWERY
# 737                             BROADWAY
# 738                           SECOND AVE
# 739                           EAST 70 ST
# 740                             LEWIS ST
# 741                        WEST 176TH ST
# 742                            LUDLOW ST
# 743                            W 21ST ST
# 744              MILLS HOTEL BLEECKER ST
# 745                              48TH ST
# 746                            FIRST AVE
# 747                          EAST 5TH ST
# 748                          EAST 117 ST
# 749                             AVENUE A
# 750                              W139 ST
# 751                        WEST 143RD ST
# 752                              W 35 ST
# 753                         EAST 14TH ST
# 754                         EAST 66TH ST
# 755                          EAST 100 ST
# 756                        EAST 110TH ST
# 757                         RIVINGTON ST
# 758                        MANHATTAN AVE
# 759                        LEXINGTON AVE
# 760                             ESSEX ST
# 761                        WEST 170TH ST
# 762                             PARK AVE
# 763                               BOWERY
# 764                              W 10 ST
# 765                        EAST 105TH ST
# 766              MILLS HOTEL BLEECKER ST
# 767                        WEST 106TH ST
# 768                              80 EAST
# 769                            COOPER SQ
# 770         68 ST BETWEEN LEXINGTON THIR
# 771                      MORNINGSIDE AVE
# 772                           SECOND AVE
# 773                            W 61ST ST
# 774                           SECOND AVE
# 775                         EAST 94TH ST
# 776                             E 6TH ST
# 777                             EAST 8TH
# 778                    BLACKWELLS ISLAND
# 779                              WEST 51
# 780                           EAST 86 ST
# 781                 RIVER PENT OF 119 TH
# 782                               W47 ST
# 783                         WEST 38TH ST
# 784                         WEST 49TH ST
# 785                       FORTY FIRST ST
# 786     WEST ONE HUNDRED AND THIRTY THIR
# 787                        AMSTERDAM AVE
# 788                              2ND AVE
# 789                          COSTUMES ST
# 790                               OAK ST
# 791                         ELIZABETH ST
# 792                            THIRD AVE
# 793                           W 128TH ST
# 794                              38TH ST
# 795                              W152 ST
# 796                            E 56TH ST
# 797                           EAST 71 ST
# 798                             ESSEX ST
# 799             ONE HUNDRED AND FIFTH ST
# 800                        EAST 118TH ST
# 801                           STANTON ST
# 802                       100 ST & 5 AVE
# 803                EAST FIFTY SEVENTH ST
# 804                           EAST 21 ST
# 805                        AMSTERDAM AVE
# 806                             E 114 ST
# 807                 MORNINGSIDE AVE WEST
# 808                            THIRD AVE
# 809                           SECOND AVE
# 810                              2ND AVE
# 811                           WEST 47 ST
# 812                         WEST END AVE
# 813                            MAIDEN LN
# 814                          ST MARKS PL
# 815                         WEST 42TH ST
# 816                         18ST ST EAST
# 817                         WEST 86TH ST
# 818                         EAST 66TH ST
# 819                           WEST 47 ST
# 820                            SPRING ST
# 821                           EAST 56 ST
# 822                             HENRY ST
# 823                        WEST 112TH ST
# 824                         ELIZABETH ST
# 825                             LEWIS ST
# 826                        EAST EIGHT ST
# 827                     18 EASY 75 TH ST
# 828                          ST MARKS PL
# 829                             TENTH ST
# 830                              8TH AVE
# 831                         ELEVENTH AVE
# 832                            ACHARD ST
# 833                           EAST 93 ST
# 834                          SEVENTH AVE
# 835                              O 43 ST
# 836                             S MAHOLA
# 837                            OLIVER ST
# 838                  WEST FIFTY FIRST ST
# 839                           WEST 72 ST
# 840                             GAARD ST
# 841                            CHERRY ST
# 842                               4TH ST
# 843                        EAST SIXTH ST
# 844                             W 4TH ST
# 845                            BAXTER ST
# 846                          WEST 150 ST
# 847                           BETHUME ST
# 848                               4TH ST
# 849                        WEST 107TH ST
# 850                             10TH AVE
# 851                                53 ST
# 852                         EAST 17TH ST
# 853                          WEST 120 ST
# 854                             PERRY ST
# 855                           WEST 19 ST
# 856     WEST ONE HUNDRED AND TWENTY FIFT
# 857                        AMSTERDAM AVE
# 858                        WEST 135TH ST
# 859                           EIGHTH AVE
# 860                            THIRD AVE
# 861                           WEST 46 ST
# 862                        EAST BROADWAY
# 863                              W116 ST
# 864                          WEST 129 ST
# 865                        EAST 121ST ST
# 866                         EAST 13TH ST
# 867                              E 77 ST
# 868                              W 45 ST
# 869                              W139 ST
# 870                         COLUMBUS AVE
# 871                                S AVE
# 872                             E 6TH ST
# 873                         ELIZABETH ST
# 874                            BAXTER ST
# 875                          EAST 8TH ST
# 876                              ORCHARD
# 877                        AMSTERDAM AVE
# 878                        EAST TENTH ST
# 879                            CHERRY ST
# 880                              82ND ST
# 881                                  W41
# 882                        WEST 132ND ST
# 883                    W THIRTY-THIRD ST
# 884                           WEST 50 ST
# 885                         EAST 90TH ST
# 886                           SHERIFF ST
# 887                           STANTON ST
# 888                 WEST FIFTY-FOURTH ST
# 889                              48TH ST
# 890                            BAXTER ST
# 891                          EAST 119 ST
# 892                          EAST 118 ST
# 893                        EAST 102ND ST
# 894                        LEXINGTON AVE
# 895               EAST SEVENTY FOURTH ST
# 896                              PITT ST
# 897                          EAST 8TH ST
# 898                           WEST 83 ST
# 899                          WEST 143 ST
# 900                         EAST 66TH ST
# 901                            E 10TH ST
# 902                      FOURTY FIFTH ST
# 903                   PIER 13 EAST RIVER
# 904                           WEST 42 ST
# 905              MILLS HOTEL BLEECKER ST
# 906                             AVENUE A
# 907                      ST NICHOLAS AVE
# 908                             THIRD ST
# 909                           WEST 23 ST
# 910                               123 ST
# 911                            CANNON ST
# 912                              PITT ST
# 913                            SIXTH AVE
# 914                          WEST 127 ST
# 915                           W 137TH ST
# 916                           SECOND ALY
# 917                      ST NICHOLAS AVE
# 918                            BALTON RD
# 919                         EAST 33RD ST
# 920                         COLUMBUS AVE
# 921                    BLACKWELLS ISLAND
# 922                             GRAND ST
# 923                         EAST 33RD ST
# 924                         EDGECOMB AVE
# 925                  WEST SEVENTEENTH ST
# 926                          EAST 105 ST
# 927               NEW YORK ATHLETIC CLUB
# 928                EAST SEVENTY THIRD ST
# 929                            BARTER ST
# 930                          SEVENTH AVE
# 931                               6TH ST
# 932                           RENNICK ST
# 933                              E 81 ST
# 934                          ATTORNEY ST
# 935                          WEST 129 ST
# 936                          CHRYSTIE ST
# 937                              PITT ST
# 938                            FIFTH AVE
# 939                  EAST UNITY FIFTH ST
# 940                          EAST 100 ST
# 941                      TWENTY SIXTH ST
# 942                          CONVENT AVE
# 943                          MADISON AVE
# 944                            BROOME ST
# 945                         WEST 93RD ST
# 946                           E 116TH ST
# 947                                69 ST
# 948                        WEST 124TH ST
# 949         68 ST BETWEEN LEXINGTON & TH
# 950                                AVE A
# 951                             ALLEN ST
# 952                           EAST 29 ST
# 953                            E 12TH ST
# 954                            OHENRY ST
# 955                              SHERIFF
# 956                            HUDSON ST
# 957                          ST MARKS PL
# 958                              62RD ST
# 959                          ELDRIDGE ST
# 960                         WEST 44TH ST
# 961                        AMSTERDAM AVE
# 962                                AVE C
# 963                           MADISON ST
# 964                         WEST 39TH ST
# 965     2205 BROODWAY (APTHORP APERTONEN
# 966                           TOMKINS ST
# 967                              22ND ST
# 968                          WEST 135 ST
# 969                         WEST 62ND ST
# 970                         WEST 59TH ST
# 971                         WEST 79TH ST
# 972                           ST 2ND AVE
# 973                        WEST 148TH ST
# 974                              3RD ALY
# 975               EAST SEVENTY FOURTH ST
# 976                            FIRST AVE
# 977                             E 112 ST
# 978                             102ND ST
# 979                           WEST 24 ST
# 980                              29TH ST
# 981                            MONROE ST
# 982                        AMSTERDAM AVE
# 983                         WEST 69TH ST
# 984                          WEST 137 ST
# 985                           W 148RD ST
# 986              MILLS HOTEL BLEECKER ST
# 987                EAST FIFTY SEVENTH ST
# 988                              22ND ST
# 989                         EAST 69TH ST
# 990                             SIXTH ST
# 991                         WEST 80TH ST
# 992                            FIRST AVE
# 993                      ST NICHOLAS AVE
# 994                             SAMES ST
# 995                         EAST 66TH ST
# 996                         WEST 43RD ST
# 997                               6TH ST
# 998                           CLINTON ST
# 999                            SECOND ST
# 1000                EAST SIXTY SECOND ST
# 1001                          WEST 10 ST
# 1002                           CHERRY ST
# 1003                               92 ST
# 1004                       EAST 117TH ST
# 1005                       WEST 170TH ST
# 1006                             E 13 ST
# 1007                       WEST 103RD ST
# 1008                                E 43
# 1009                          EAST 78 ST
# 1010                       EAST 115TH ST
# 1011                           MONROE ST
# 1012                         EAST 108 ST
# 1013                           FIRST AVE
# 1014                        WEST 49TH ST
# 1015                         WEST 109 ST
# 1016                         EAST 114 ST
# 1017                          EAST 60 ST
# 1018                               AVE W
# 1019     EAST ONE HUNDRED TWENTIETH STEE
# 1020                           SPRING ST
# 1021                        WEST 80TH ST
# 1022                         EAST 116 ST
# 1023                        EAST 11TH ST
# 1024                             7TH AVE
# 1025                            MCDOUGAL
# 1026                          BASFORD ST
# 1027                WEST NINETY SIXTH ST
# 1028                        EAST 81ST ST
# 1029                          SECOND AVE
# 1030                           FIRST AVE
# 1031        68 ST BETWEEN LEXINGTON & TH
# 1032                       WEST 142ND ST
# 1033                           LENOX AVE
# 1034                             W120 ST
# 1035                             PELL ST
# 1036                          WEST 81 ST
# 1037                          FOURTH AVE
# 1038                         MADISON AVE
# 1039                       AMSTERDAM AVE
# 1040                        EAST 99TH ST
# 1041                            AVENUE B
# 1042                             E 73 ST
# 1043                       WEST 139TH ST
# 1044                        EAST 67TH ST
# 1045                          WEST 39 ST
# 1046                    NS OF WEST 62 ST
# 1047                        WEST 124W ST
# 1048                       EAST SIXTH ST
# 1049                        WEST 90TH ST
# 1050                        EAST 53RD ST
# 1051                            E 114 ST
# 1052                       WEST 170TH ST
# 1053                           W 51ST ST
# 1054                            GAARD ST
# 1055                         116 ST WEST
# 1056                        ELIZABETH ST
# 1057                           E 43RD ST
# 1058                              121 ST
# 1059                         WEST 151 ST
# 1060                       WEST 127TH ST
# 1061                EAST FOURTH (4TH) ST
# 1062                            SIXTH ST
# 1063        SOUTH WEST THIRTY SEVENTH ST
# 1064                            AVENUE-B
# 1065                       WEST 118TH ST
# 1066                         MULBERRY ST
# 1067                       LEXINGTON AVE
# 1068                         WEST 156 ST
# 1069                               45 ST
# 1070                          EAST 16 ST
# 1071                            E 5TH ST
# 1072                WEST THIRTY FIRST ST
# 1073                          EAST 72 ST
# 1074                             JANE ST
# 1075                          SUFFOLK ST
# 1076                        WEST 61ST ST
# 1077                         EAST 105 ST
# 1078                       WEST 113TH ST
# 1079                             21ST ST
# 1080                         EAST 3RD ST
# 1081                             5TH AVE
# 1082                          EAST 84 ST
# 1083                        EAST 77TH ST
# 1084                              117 ST
# 1085                         MULBERRY ST
# 1086                            AVENUE C
# 1087                        MACDOUGAL ST
# 1088                           BAXTER ST
# 1089                         WEST 118 ST
# 1090                          WEST 31 ST
# 1091                        EAST 69 F ST
# 1092    2205 BROODWAY (APTHORP APERTONEN
# 1093                        WEST 49TH ST
# 1094                            10TH AVE
# 1095                            10TH AVE
# 1096                         SEVENTH AVE
# 1097                             W 45 ST
# 1098                            AVENUE A
# 1099                           HUBERT ST
# 1100                           SPRING ST
# 1101                            CHERY ST
# 1102                        WEST 81TH ST
# 1103                        ELIZABETH ST
# 1104                          JACKSON ST
# 1105                             3RD AVE
# 1106                           W 138H ST
# 1107                            THIRD ST
# 1108                        EAST 56TH ST
# 1109            ONE HUNDRED AND EIGHT ST
# 1110                        MACDOUGAL ST
# 1111                       WEST 118TH ST
# 1112                          BEDFORD ST
# 1113                          WEST 27 ST
# 1114                          SECOND AVE
# 1115                        EAST 15TH ST
# 1116                          ORCHARD ST
# 1117                             22ND ST
# 1118                       EAST 103RD ST
# 1119                          51 ST WEST
# 1120                          WEST 94 ST
# 1121                      1ST (FIRST AVE
# 1122                       AMSTERDAM AVE
# 1123                       WEST 161ST ST
# 1124                             W 35 ST
# 1125                        EAST 77TH ST
# 1126                             W 26 ST
# 1127                       WEST 121ST ST
# 1128                        EAST 72ND ST
# 1129                         SEVENTH AVE
# 1130                        LAFAYETTE ST
# 1131                             7TH AVE
# 1132                            PARK AVE
# 1133                        WEST 76TH ST
# 1134                         EAST 100 ST
# 1135                          SUFFOCK ST
# 1136                           E 96TH ST
# 1137                        WEST 37TH ST
# 1138                       WEST 103RD ST
# 1139                     ST NICHOLAS AVE
# 1140                            AVENUE A
# 1141                       WEST 113TH ST
# 1142                        ELIZABETH ST
# 1143                          STANTON ST
# 1144                            10TH AVE
# 1145                            109TH ST
# 1146                         SEVENTH AVE
# 1147                          E 112TH ST
# 1148                             3RD AVE
# 1149                      RIVERVILLE AVE
# 1150                     EAST HOUSTON ST
# 1151                  WEST EIGHTEENTH ST
# 1152                         EAST 118 ST
# 1153                        EAST 31ST ST
# 1154                         WEST 173 ST
# 1155                            ALLEN ST
# 1156                            FRIST ST
# 1157                           FIFTH AVE
# 1158                            AVENUE B
# 1159                             13TH ST
# 1160                       EAST 119TH ST
# 1161                   BLACKWELLS ISLAND
# 1162                             99TH ST
# 1163                            AVENUE A
# 1164                       WEST 117TH ST
# 1165                          EAST 87 ST
# 1166                       EAST 119TH ST
# 1167                        WEST 80TH ST
# 1168                       EAST 110TH ST
# 1169                       WEST 163RD ST
# ...
# 1611                 EAST FIFTY FIRST ST
# 1612                            AVENUE B
# 1613                       AMSTERDAM AVE
# 1614                          1729 2 AVE
# 1615                          EAST 85 ST
# 1616                       WEST 160TH ST
# 1617                         WEST 155 ST
# 1618                          EAST 59 ST
# 1619                        WEST 47TH ST
# 1620                         EAST 100 ST
# 1621                        RIVINGTON ST
# 1622                 18 ST BET 7 & 8 AVE
# 1623                        JEFFERSON ST
# 1624                            E 6TH ST
# 1625                           E 75TH ST
# 1626     EAST ONE HUNDRED AND EIGHTEENTH
# 1627                            122ND ST
# 1628                         DELANCEY ST
# 1629                         EAST 120 ST
# 1630                          EAST 41 ST
# 1631                           FIRST AVE
# 1632                          EAST 24 ST
# 1633                            HENRY ST
# 1634                              121 ST
# 1635                       WEST 136TH ST
# 1636                        WEST 61ST ST
# 1637                         CHRYSTIE ST
# 1638                          CHARLES ST
# 1639                           THIRD AVE
# 1640                         WEST 132 ST
# 1641                         WEST 139 ST
# 1642                       EAST 106TH ST
# 1643                            PERRY ST
# 1644        68 ST BETWEEN LEXINGTON THIR
# 1645                         EAST 5TH ST
# 1646                       EAST 123RD ST
# 1647                          ELDRIGE ST
# 1648                        VARN DARN ST
# 1649                      EAST 11 8TH ST
# 1650                           HESTER ST
# 1651                        WEST 60TH ST
# 1652                         EAST 108 ST
# 1653                     FOURTY FIFTH ST
# 1654                        COLUMBUS AVE
# 1655              B'WAY 44TH TO 45TH STS
# 1656           ONE HUNDRED NIGHT ST WEST
# 1657                             2ND AVE
# 1658                       EAST 104TH ST
# 1659                             PELL ST
# 1660                 EAST SIXTY THIRD ST
# 1661                            PARK AVE
# 1662                             STANTON
# 1663     EAST ONE HUNDRED AND FOURTEENTH
# 1664                        RIVERSIDE DR
# 1665           EAST 16ST ST EAST 16ST ST
# 1666                         HAMILTON PL
# 1667                            PARK AVE
# 1668                       AMSTERDAM AVE
# 1669                             8TH AVE
# 1670                          EAST 88 ST
# 1671            WEST 19 ST BET 7 & 8 AVE
# 1672                        EAST 31ST ST
# 1673           ONE HUNDRED AND SECOND ST
# 1674                          WEST 78 ST
# 1675                         WEST 140 ST
# 1676                         SEVENTH AVE
# 1677                       WEST 121ST ST
# 1678                           TENTH AVE
# 1679                       EAST 107TH ST
# 1680                      329 EAST 63 ST
# 1681                          EAST 96 ST
# 1682                         EAST 101 ST
# 1683                          ORCHARD ST
# 1684                        WEST 63RD ST
# 1685                          CLINTON ST
# 1686                         FORTIETH ST
# 1687                         EAST 109 ST
# 1688                       EAST 107TH ST
# 1689                     EAST HOUSTON ST
# 1690                            E 42D ST
# 1691                        WEST 48TH ST
# 1692                               52 ST
# 1693          NINETY-FOURTH ST (94TH ST)
# 1694                             PITT ST
# 1695                            ALLEN ST
# 1696                        EAST 69TH ST
# 1697                        RIVINGTON ST
# 1698                        EAST 53RD ST
# 1699                        WEST 74TH ST
# 1700                         WEST 143 ST
# 1701               EAST SEVENTY FIFTH ST
# 1702                             22ND ST
# 1703                           LUDLOW ST
# 1704                            SIXTH ST
# 1705                        EAST 55TH ST
# 1706                       EAST SIXTH ST
# 1707                            LEWIS ST
# 1708                        EAST 62ND ST
# 1709                          STANTON ST
# 1710                          EAST 77 ST
# 1711                        ELEVENTH AVE
# 1712                         78 ST NS 10
# 1713                       AMSTERDAM AVE
# 1714                        EAST 70TH ST
# 1715                       E MORNINGSIDE
# 1716                         EAST 117 ST
# 1717                       EAST 114TH ST
# 1718                       WEST 143RD ST
# 1719                       125TH ST WEST
# 1720                          WEST 27 ST
# 1721                       EAST FIFTH ST
# 1722                        WEST 66TH ST
# 1723                          CLINTON ST
# 1724                             27TH ST
# 1725                          MADISON ST
# 1726                       EAST THIRD ST
# 1727                              3D AVE
# 1728                       WEST 110TH ST
# 1729                        HAMILTON TER
# 1730                     EAST HOUSTON ST
# 1731                        EAST 72ND ST
# 1732                          MADISON ST
# 1733                        COLUMBUS AVE
# 1734                        18TH ST EAST
# 1735                            166TH ST
# 1736                          ELDRIGE ST
# 1737                             E 65 ST
# 1738                            137TH ST
# 1739                       EAST 113TH ST
# 1740                        FRIAOT ARECA
# 1741                              E46 ST
# 1742                 WEST FIFTY FIRST ST
# 1743                         EAST 6TH ST
# 1744                             11TH ST
# 1745    26 ST TO 28 ST E FIRST AVE & E R
# 1746                        EAST 82ND ST
# 1747                          MADISON ST
# 1748             MILLS HOTEL BLEECKER ST
# 1749                        WEST 66TH ST
# 1750                EAST EIGHTY-FIFTH ST
# 1751                     EAST SEVENTH ST
# 1752                        WEST 36TH ST
# 1753                         115 ST WEST
# 1754                            RIDGE ST
# 1755                      100 ST & 5 AVE
# 1756                        EAST 32ND ST
# 1757                          WEST 94 ST
# 1758                          EAST 64 ST
# 1759                           FIFTH AVE
# 1760                            BROADWAY
# 1761                          SUFFOLK ST
# 1762                            AVENUE A
# 1763                       WEST 175TH ST
# 1764                        WEST 82ND ST
# 1765                             AMS AVE
# 1766                    WEST FIFTY THIRD
# 1767                            76TH AVE
# 1768                        ELIZABETH ST
# 1769                    WEST FIFTY THIRD
# 1770                       WASHINGTON ST
# 1771                           LUDLOW ST
# 1772                               8 AVE
# 1773         AMSTERDAM AVE 136 TO 138 ST
# 1774                     CART 99TH THIRD
# 1775                         MC COMBS PL
# 1776                             84TH ST
# 1777                    EIGHTY EIGHTH ST
# 1778                          W 181ST ST
# 1779                 WEST SEVENTEENTH ST
# 1780                             37TH ST
# 1781                          RENDALL ST
# 1782                         THOMPSON ST
# 1783                          WEST 42 ST
# 1784                            GERRY ST
# 1785                          STANTON ST
# 1786                 WEST 130 ST NO SIDE
# 1787                               AVE D
# 1788                           CHERRY ST
# 1789                        EAST 17TH ST
# 1790                              W42 ST
# 1791                        EAST 34TH ST
# 1792                           E 66TH ST
# 1793                EAST EIGHTY THIRD ST
# 1794                        EAST 73RD ST
# 1795                            MCDOUGAL
# 1796                         WEST 146 ST
# 1797                       GANZEVOORT ST
# 1798                        WEST 10TH ST
# 1799                        ELIZABETH ST
# 1800                       EAST FIFTH ST
# 1801                     EAST HOUSTON ST
# 1802                WEST THIRTY THIRD ST
# 1803                WEST TWENTY NINTH ST
# 1804                             O 43 ST
# 1805                            AVENUE B
# 1806                     ST NICHOLAS AVE
# 1807                     EAST SEVENTH ST
# 1808                           CHERRY ST
# 1809                         EAST 119 ST
# 1810                             39TH ST
# 1811                       EAST 114TH ST
# 1812                       EAST 112TH ST
# 1813        EAST EIGHTY SEVENTH ST (87TH
# 1814               EAST EIGHTY SECOND ST
# 1815                            119TH ST
# 1816                       EAST 127TH ST
# 1817                             16TH ST
# 1818     EAST ONE HUNDRED AND FOURTEENTH
# 1819                           E-77TH ST
# 1820                          WEST 12 ST
# 1821                    EIGHTY-SECOND ST
# 1822                        EAST 15TH ST
# 1823                        WEST 19TH ST
# 1824                             PELL ST
# 1825                        WEST 80TH ST
# 1826                            AVENUE A
# 1827                       AMSTERDAM AVE
# 1828                          EAST 83 ST
# 1829                          SECOND AVE
# 1830                              BOWERY
# 1831                             3RD AVE
# 1832                            HENRY ST
# 1833                             1ST AVE
# 1834                               AVE A
# 1835                           W 26TH ST
# 1836                             9TH AVE
# 1837                           E 44TH ST
# 1838                           FIRST AVE
# 1839                               AVE D
# 1840        68 ST BETWEEN LEXINGTON & TH
# 1841                          E 115TH ST
# 1842                         WEST 136 ST
# 1843                       116TH ST WEST
# 1844                        WEST 78TH ST
# 1845                        EAST 35TH ST
# 1846                        EAST 11TH ST
# 1847                    EAST ELEVENTH ST
# 1848                        RIVINGTON ST
# 1849                           PRINCE ST
# 1850                        EAST 55TH ST
# 1851                      EAST SECOND ST
# 1852                          WEST 76 ST
# 1853                       GRACEWOOD AVE
# 1854                        WEST 47TH ST
# 1855                        EAST 10TH ST
# 1856                         MINNETTE ST
# 1857                            109TH ST
# 1858                       WEST 159TH ST
# 1859                        EAST 98TH ST
# 1860                             W 83 ST
# 1861                        ELIZABETH ST
# 1862                    EIGHTH (8TH) AVE
# 1863                       GANZEVOORT ST
# 1864                              100 ST
# 1865                              BOWERY
# 1866                            ALLEN ST
# 1867                               49 ST
# 1868                            ESSEX ST
# 1869                       EDGECOMBE ALY
# 1870                     SIXTY SECOND ST
# 1871                                E 81
# 1872                            THIRD ST
# 1873                          EAST 77 ST
# 1874                      329 EAST 63 ST
# 1875                               W 113
# 1876                        WEST 30TH ST
# 1877                             W 45 ST
# 1878                        RIVINGTON ST
# 1879                   CENTRAL PARK WEST
# 1880    EAST ONE HUNDRED TWENTY FIRST ST
# 1881                        EAST 92ND ST
# 1882                          W 142ND ST
# 1883                           E 81ST ST
# 1884                        WEST 64TH ST
# 1885               EAST SEVENTY THIRD ST
# 1886                 EAST NINTY NINTH ST
# 1887                       EAST BROADWAY
# 1888                        WEST 36TH ST
# 1889                       WEST 179AT ST
# 1890                         EAST 5TH ST
# 1891                        EERO TWELFTH
# 1892                          EAST 86 ST
# 1893                            THIRD ST
# 1894                        EAST 72ND ST
# 1895                          E 131ST ST
# 1896                         CLARKSON ST
# 1897                       WEST 165TH ST
# 1898                         MINNETTA ST
# 1899                       100TH ST EAST
# 1900                      EAST 11 8TH ST
# 1901                       AMSTERDAM AVE
# 1902                         CHRYSTIE ST
# 1903                            114TH ST
# 1904                          WEST 19 ST
# 1905                       WEST 113TH ST
# 1906                         COMMERCE ST
# 1907                          WEST 57 ST
# 1908                          SECOND AVE
# 1909                        EAST 39TH ST
# 1910                            RIDGE ST
# 1911                             W 109TH
# 1912                         MADISON AVE
# 1913                        WEST 44TH ST
# 1914                     EAST SEVENTH ST
# 1915                            SULLIVAN
# 1916                         EAST 100 ST
# 1917                             19TH ST
# 1918                         WEST 158 ST
# 1919                        EAST 97TH ST
# 1920                        EIGHTIETH ST
# 1921                            BROADWAY
# 1922                       EAST 110TH ST
# 1923                       WEST 178TH ST
# 1924                             7TH AVE
# 1925                            113TH ST
# 1926                             MOTT ST
# 1927                             E 27 ST
# 1928                          EIGHTH AVE
# 1929                          MADISON ST
# 1930                         EAST 116 ST
# 1931                          WILLETT ST
# 1932                               W 136
# 1933                           W 61ST ST
# 1934                             8TH AVE
# 1935                         SEVENTH AVE
# 1936                            CAMEL ST
# 1937                            PERRY ST
# 1938                               W 118
# 1939                       AMSTERDAM AVE
# 1940                            W 147 ST
# 1941                             88TH ST
# 1942           WEST 19TH ST BET ST 8 AVE
# 1943                            SEVEN ST
# 1944                        WEST 56ST ST
# 1945                          EAST 75 ST
# 1946                            HENRY ST
# 1947                            PARK AVE
# 1948                         CHRYSTIE ST
# 1949                               19 ST
# 1950                               42 ST
# 1951                            11TH AVE
# 1952                        EAST 67TH ST
# 1953                               AVE B
# 1954                            E 118 ST
# 1955                        WEST 41ST ST
# 1956                         MULBERRY ST
# 1957                          SEVENTH ST
# 1958                         WEST 147 ST
# 1959                       MANHATTON AVE
# 1960                     SIXTY SECOND ST
# 1961                       EAST TENTH ST
# 1962                       EAST 106TH ST
# 1963                        RIVINGTON ST
# 1964                         THOMPSON ST
# 1965                          SECOND AVE
# 1966                          ORCHARD ST
# 1967                         HAMILTON ST
# 1968                   BLACKWELLS ISLAND
# 1969                          WEST 96 ST
# 1970               WEST THIRTY FOURTH ST
# 1971                         ATTORNEY ST
# 1972                             E 81 ST
# 1973                        EAST 62ND ST
# 1974                       WEST 178TH ST
# 1975                       RINER AL DAIR
# 1976                       WEST 135TH ST
# 1977                        GREENWICK ST
# 1978                            BROADWAY
# 1979                          EAST 82 ST
# 1980                       EAST 115TH ST
# 1981                        EAST 12TH ST
# 1982                       WEST 123RD ST
# 1983           ONE HUNDRED AND SECOND ST
# 1984                        EAST 12TH ST
# 1985                          SUFFOLK ST
# 1986                       EAST 110TH ST
# 1987                       WEST 106TH ST
# 1988                        WEST 15TH ST
# 1989                       WEST 142ND ST
# 1990                  EAST SEVENTIETH ST
# 1991                           FIFTH AVE
# 1992                          WEST 50 ST
# 1993                         WEST 4TH ST
# 1994                          SECOND AVE
# 1995                         WEST 158 ST
# 1996                           E 78TH ST
# 1997                             8TH AVE
# 1998                       LEXINGTON AVE
# 1999                       609 E 14TH ST
# Name: Street address 2, dtype: object

# %%
df.street_name_clean.unique()
# Out:
# array([''], dtype=object)

# %%
print(df['street_type_clean'])
print(df['street_type_clean'].unique())
# Out:
# 0        ST
# 1        ST
# 2        ST
# 3        ST
# 4        ST
#        ...
# 1995     ST
# 1996     ST
# 1997    AVE
# 1998    AVE
# 1999     ST
# Name: street_type_clean, Length: 2000, dtype: object
# ['ST' '' 'AVE' 'PL' 'CIR' 'ALY' 'PARK' 'SQ' 'LN' 'DR' 'TER']

# %%
class Street:
    def street_type(x):
        pattern = re.compile(r'\sSTREET|\sSTR|\sSTE$|\sSRT$|\sSR$\s|\sSST$|\sSEET$|\sTREET$|\sSHEER$|\sSHEE$|\sSTREE$|\sSREET$|\sREET$|\sSTEE$|\sST$')
        x = re.sub(pattern, " ST", x)
        pattern = re.compile(r'\sDRIVE$|\sDRV$|\sDRI$|\sDRIV$|\sDRIE$|\sD.$')
        x = re.sub(pattern, " DR", x)
        pattern = re.compile(r'\sCIRCLE$|\sCIRCL$|\sCICLE$|\sCIRC$|\sCIR$|\sCRL$|\sC.$')
        x = re.sub(pattern, " CIR", x)
        pattern = re.compile(r'\sAVENUE$|\sAVENU$|\sAVEN$|\sAVE$|\sAVN$\sAV$')
        x = re.sub(pattern, " AVE", x)
        pattern = re.compile(r"\sCOURT$|\sCT$|\sCRT$|\sCTR$|\sCOUR$|<=\sCOT$|\sCORT$")
        x = re.sub(pattern, " CT", x)
        pattern = re.compile(r"\sBOULEVARD$|\sBVLD|\sBL.$|\sB.$")
        x = re.sub(pattern, " BLVD", x)
        pattern = re.compile(r"\sROAD$|\sRD$|\sRAD$|\sROD$")
        x = re.sub(pattern, " RD", x)
        pattern = re.compile(r"\sALLEY$|\sALY$|\sALEY$|\sALL.$|\sA.$")
        x = re.sub(pattern, " ALY", x)
        pattern = re.compile(r"\sPLACE$|\sPL.$|\sP.$|\sPLAC$|\sPLCE$|\sPCE$")
        x = re.sub(pattern, " PL", x)
        pattern = re.compile(r"\sPK$|\sPRK$|\sPRAK$|\sPAK$")
        x = re.sub(pattern, " PARK", x)
        pattern = re.compile(r"\sPARKWAY$|\sPKWY$|\sPARKW$|\sPWY$|\sPKW$|\sPRKWY$|\sPKW$")
        x = re.sub(pattern, " PKWY", x)
        pattern = re.compile(r"\sAPPROA$|\sAPRCH$|\sAPPRCH$|\sAPPR$|\sAPR$")
        x = re.sub(pattern, " APPROACH", x)
        pattern = re.compile(r"\sTERRACE$|\sTERR$|\sTER$|\sTRCE$|\sTRC$|\sTR$")
        x = re.sub(pattern, " TER", x)
        pattern = re.compile(r"\sPLAZA$|\sPLZA$|\sPLZ$|\sPLAZ$|\sPZ$")
        x = re.sub(pattern, " PLZ", x)
        pattern = re.compile(r"\sLANE$|\sLNE$|\sLN$|\sLAN$")
        x = re.sub(pattern, " LN", x)
        pattern = re.compile(r"\sBRIDGE$|\sBRGD$|\sBRG$|\sBGE$")
        x = re.sub(pattern, " BRG",x)
        pattern = re.compile(r"\sHILL$|\sHLL$|\sHL$|\sHIL$")
        x = re.sub(pattern, " HL", x)
        pattern = re.compile(r"\sHEIGHTS$|\sHTS$|\sHT$|\sHEGHTS$|\sHEIGHT$|\sHHT$|\sHEIGT$") 
        x = re.sub(pattern, " HTS", x)
        pattern = re.compile(r"\sSLP$|\sSLEP$|\sSLIIP$|\sSLI$")
        x = re.sub(pattern, " SLIP", x)
        pattern = re.compile(r"\sROOW$|\sRO.$|\sRW$")
        x = re.sub(pattern, " ROW", x)
        pattern = re.compile(r"\sSQUARE$") 
        x = re.sub(pattern, " SQ", x)
        
        return x
    
    def direction(x):
         # The orientations in the addresses
        pattern = re.compile(r'\sN\s')
        re.sub(pattern, " N ", x)
        pattern = re.compile(r'\sS\s')
        re.sub(pattern, " S ", x)
        pattern = re.compile(r'\sE\s')
        re.sub(pattern, " E ", x)
        pattern = re.compile(r'\sW\s')
        re.sub(pattern, " W ", x)
        
        return x

    def street_name_clean(x):
        pattern = re.compile(r'^\bST\b')
        x = re.sub(pattern, "SAINT", x)
        pattern = re.compile(r'\sHOUSE|\sHOSTEL|\sHOTEL|\sLODGE|\sLODGING')
        x = re.sub(pattern,"", x)
        
        pattern = re.compile(r'(\s|^)ALLANTIC|(\s|^)ATLASTA')
        x = re.sub(pattern, "ATLANTIC", x)
        pattern = re.compile(r'(\s|^)ALLEM')
        x = re.sub(pattern, "ALLEN", x)    
   
        pattern = re.compile(r'(\s|^)CROTON|(\s|^)GROTON')
        x = re.sub(pattern, "AUDUBON", x)    
        pattern = re.compile(r'(\s|^)(AT RINS)')
        x = re.sub(pattern, "ATKINS", x)     

        pattern = re.compile(r'(\s|^)BATTIE')
        x = re.sub(pattern, "BALTIC", x)      
        pattern = re.compile(r'(\s|^)BARREE')
        x = re.sub(pattern, "BARROW", x)   
        pattern = re.compile(r'(\s|^)BESSHLEY')
        x = re.sub(pattern, "BURLING", x)       
        pattern = re.compile(r'(\s|^)BIRY|(\s|^)(B WAY)|(\s|^)BWAY|(\s|^)BRAKSWAY')
        x = re.sub(pattern, "BROADWAY", x)         
        pattern = re.compile(r'(\s|^)BUSTWICK')
        x = re.sub(pattern, "BUSHWICK", x) 
        pattern = re.compile(r'(\s|^)BUTTER')
        x = re.sub(pattern, "BUTLER", x) 
        pattern = re.compile(r'(\s|^)BREEVORT')
        x = re.sub(pattern, "BREVOORT", x) 
        pattern = re.compile(r'(\s|^)BRENNEL|\sBROOMES\s|\sBROOM|(\s|^)BRANNAS|(\s|^)BROWN')
        x = re.sub(pattern, "BROOME", x) 
        pattern = re.compile(r'(\s|^)BLACKER|(\s|^)BLENKER')
        x = re.sub(pattern, "BLEECKER", x) 

        pattern = re.compile(r'(\s|^)CLAIR')
        x = re.sub(pattern, "CLASSON", x) 
        pattern = re.compile(r'(\s|^)CLISTEN')
        x = re.sub(pattern, "CLINTON", x)     
        pattern = re.compile(r'(\s|^)CHERY')
        x = re.sub(pattern, "CHERRY", x) 
        pattern = re.compile(r'(\s|^)CHRYSTEE|(\s|^)CHRYSTAL|(\s|^)CHTYSTIE|(\s|^)CHRYSTEL')
        x = re.sub(pattern, "CHRYSTIE", x)     
        pattern = re.compile(r'(\s|^)CARRAL|(\s|^)COYAL')
        x = re.sub(pattern, "CANAL", x)    
        pattern = re.compile(r'(\s|^)COLUMBIN')
        x = re.sub(pattern, "COLUMBIA", x) 
        pattern = re.compile(r'(\s|^)CAMNON')
        x = re.sub(pattern, "CANNON", x) 
        pattern = re.compile(r'(\s|^)CROWH')
        x = re.sub(pattern, "CROWN", x) 

        pattern = re.compile(r'(\s|^)DEVAL')
        x = re.sub(pattern, "DEVOE", x)
        pattern = re.compile(r'(\s|^)DEBOUCHEL')
        x = re.sub(pattern, "DEBEVOISE",x)
        pattern = re.compile(r'(\s|^)DAFONT')
        x = re.sub(pattern, "DUPONT", x)
        pattern = re.compile(r'(\s|^)DEGRAN')
        x = re.sub(pattern, "DEGRAW", x)
        pattern = re.compile(r'(\s|^)DENBO|(\s|^)DEKALB')
        x = re.sub(pattern, "DE KALB", x)
        pattern = re.compile(r'(\s|^)DELAMERE|(\s|^)DALANEY|(\s|^)DELANEY|(\s|^)DELANCY')
        x = re.sub(pattern, "DELANCEY", x) 

        pattern = re.compile(r'(\s|^)ELTHZROTH|(\s|^)ELLSWICK')
        x = re.sub(pattern, "ELLIOTT", x)
        pattern = re.compile(r'(\s|^)ELDREDGE|(\s|^)CLARIDGE')
        x = re.sub(pattern, "ELDRIDGE", x) 
        pattern = re.compile(r'(\s|^)ESSEY')
        x = re.sub(pattern, "ESSEX", x) 

        pattern = re.compile(r'(\s|^)FORSYTHE')
        x = re.sub(pattern, "FORSYTH", x) 
        pattern = re.compile(r'(\s|^)FLATHISH')
        x = re.sub(pattern, "FLATBUSH", x)

        pattern = re.compile(r'(\s|^)GLANCE')
        x = re.sub(pattern, "GRAND", x) 
        pattern = re.compile(r'(\s|^)GOAST')
        x = re.sub(pattern, "GOERCK", x)
        pattern = re.compile(r'(\s|^)GREENS')
        x = re.sub(pattern, "GREENE", x)
        pattern = re.compile(r'(\s|^)GREENRICH|(\s|^)GAMWICH')
        x = re.sub(pattern, "GREENWICH", x) 

        pattern = re.compile(r'(\s|^)HOUTON')
        x = re.sub(pattern,  "HOUSTON", x) 
        pattern = re.compile(r'(\s|^)HAVES')
        x = re.sub(pattern, "HEWES", x) 
        pattern = re.compile(r'(\s|^)HAKEY')
        x = re.sub(pattern, "HALSEY", x)
        pattern = re.compile(r'(\s|^)HEWEY')
        x = re.sub(pattern, "HENRY", x)
        pattern = re.compile(r'(\s|^)HICK')
        x = re.sub(pattern, "HICKS", x)
        pattern = re.compile(r'(\s|^)HUMBOLOT|(\s|^)HUMBARD|(\s|^)HUMBOLT')
        x = re.sub(pattern, "HUMBOLDT", x) 

        pattern = re.compile(r'(\s|^)JOHOM')
        x = re.sub(pattern, "JOHNS", x) 

        pattern = re.compile(r'(\s|^)KIOP|(\s|^)HEAP')
        x = re.sub(pattern, "KEAP", x) 

        pattern = re.compile(r'(\s|^)(LAY FAY ESTE)|(\s|^)LADORATT|(\s|^)LAFYAYETTE')
        x = re.sub(pattern, "LAFAYETTE", x)
        pattern = re.compile(r'(\s|^)LIRA|(\s|^)LOUMOR|(\s|^)LARMER')
        x = re.sub(pattern, "LORIMER", x)
        pattern = re.compile(r'(\s|^)LAAVIUK')
        x = re.sub(pattern, "LAWRENCE", x) 
        pattern = re.compile(r'(\s|^)LAIDLOW')
        x = re.sub(pattern, "LUDLOW", x) 
        pattern = re.compile(r'(\s|^)TEX|LEX(?=\s)') # perl = True
        x = re.sub(pattern, "LEXINGTON", x)   
        pattern = re.compile(r'(\s|^)REPPERTS')
        x = re.sub(pattern, "LEFFERTS", x)

        pattern = re.compile(r'(\s|^)PARLE|(\s|^)MALLE|(\s|^)MYETTE')
        x = re.sub(pattern, "MYRTLE", x)
        pattern = re.compile(r'(\s|^)(MC DOUGALL)|(\s|^)(MC DOUGAL)|(\s|^)(MCDOUGALL)')
        x = re.sub(pattern, "MCDOUGAL", x)
        pattern = re.compile(r'(\s|^)(MC DONOUGH)')
        x = re.sub(pattern, "MCDONOUGH", x)
        pattern = re.compile(r'(\s|^)MANZA|(\s|^)MAREY')
        x = re.sub(pattern, "MARCY", x)
        pattern = re.compile(r'(\s|^)MESCOLE')
        x = re.sub(pattern, "MESEROLE", x)
        pattern = re.compile(r'(\s|^)MEASE')
        x = re.sub(pattern, "MOORE", x)
        pattern = re.compile(r'(\s|^)MEDDLER')
        x = re.sub(pattern, "MIDDLETON", x)
        pattern = re.compile(r'(\s|^)MANGEN')
        x = re.sub(pattern, "MANGIN", x)
        pattern = re.compile(r'(\s|^)HAULL|(\s|^)MALLERY')
        x = re.sub(pattern, "MULBERRY", x)

        pattern = re.compile(r'(\s|^)NAPOLK')
        x = re.sub(pattern, "NORFOLK", x)
        pattern = re.compile(r'(\s|^)(VAST AND)')
        x = re.sub(pattern, "NOSTRAND", x)

        pattern = re.compile(r'(\s|^)DAK')
        x = re.sub(pattern, "OAK", x)
        pattern = re.compile(r'(\s|^)OLWEN')
        x = re.sub(pattern, "OLIVER", x)
        pattern = re.compile(r'(\s|^)GERHARD')
        x = re.sub(pattern, "ORCHARD", x)

        pattern = re.compile(r'(\s|^)PUTT')
        x = re.sub(pattern, "PITT", x)
        pattern = re.compile(r'(\s|^)PERROTT|(\s|^)(PERROTT PREMPONT)')
        x = re.sub(pattern, "PIERREPONT", x)
        pattern = re.compile(r'(\s|^)PLAD')
        x = re.sub(pattern, "PLACE", x)
        pattern = re.compile(r'(\s|^)PRUFER')
        x = re.sub(pattern, "PROSPECT", x)
        pattern = re.compile(r'(\s|^)PREDIDUNT')
        x = re.sub(pattern, "PRESIDENT", x)
        pattern = re.compile(r'(\s|^)PALOKA')
        x = re.sub(pattern, "PULASKI", x)

        pattern = re.compile(r'(\s|^)RUTHIE')
        x = re.sub(pattern, "RUTLEDGE", x)
        pattern = re.compile(r'(\s|^)RIDAL')
        x = re.sub(pattern, "RIDGE", x)
        pattern = re.compile(r'(\s|^)RAYSON')
        x = re.sub(pattern, "RYERSON", x)
        pattern = re.compile(r'(\s|^)REVENTON')
        x = re.sub(pattern, "RIVINGTON", x)
        pattern = re.compile(r'(\s|^)RUALMAINE|(\s|^)(RICER SIDE)')
        x = re.sub(pattern, "RIVERSIDE", x)
        pattern = re.compile(r'(\s|^)REDERICK|(\s|^)RENNICK')
        x = re.sub(pattern, "RENWICK", x)

        pattern = re.compile(r'(\s|^)SELLTOWN')
        x = re.sub(pattern, "SULLIVAN", x)
        pattern = re.compile(r'(\s|^)SISH')
        x = re.sub(pattern, "SIDE", x)
        pattern = re.compile(r'(\s|^)STUCKER')
        x = re.sub(pattern, "STEUBEN", x)
        pattern = re.compile(r'(\s|^)STATES')
        x = re.sub(pattern, "STATE", x)
        pattern = re.compile(r'(\s|^)SCHAALS')
        x = re.sub(pattern, "SCHOLES", x)
        pattern = re.compile(r'(\s|^)SUMME')
        x = re.sub(pattern, "SUMMIT", x)
        pattern = re.compile(r'(\s|^)SCHOMERDOSA')
        x = re.sub(pattern, "SCHERMERHORN", x)
        pattern = re.compile(r'(\s|^)DOUTH|(\s|^)SONSE')
        x = re.sub(pattern, "SOUTH", x)
        pattern = re.compile(r'(\s|^)STUYVESTANT')
        x = re.sub(pattern, "STUYVESANT", x)

        pattern = re.compile(r'(\s|^)STONPSON')
        x = re.sub(pattern, "THOMPSON", x)
        pattern = re.compile(r'(\s|^)TRAY')
        x = re.sub(pattern, "TROY", x)
        pattern = re.compile(r'(\s|^)TAYLER')
        x = re.sub(pattern, "TAYLOR", x)

        pattern = re.compile(r'(\s|^)WMON')
        x = re.sub(pattern, "UNION", x)

        pattern = re.compile(r'(\s|^)(WAR CAREN)')
        x = re.sub(pattern, "VAN BUREN", x)
        pattern = re.compile(r'(\s|^)VEMON')
        x = re.sub(pattern, "VERNON", x)
        pattern = re.compile(r'(\s|^)VANDERLY|(\s|^)VANDERSLIDE')
        x = re.sub(pattern, "VANDERBILT", x)

        pattern = re.compile(r'(\s|^)WYONIA')
        x = re.sub(pattern, "WYONA", x)
        pattern = re.compile(r'(\s|^)WITKINS')
        x = re.sub(pattern, "WATKINS", x)
        pattern = re.compile(r'(\s|^)WALLWORTH')
        x = re.sub(pattern, "WALWORTH", x)
        pattern = re.compile(r'(\s|^)WHIPPER')
        x = re.sub(pattern, "WHIPPLE", x)
        pattern = re.compile(r'(\s|^)WALLABANK|(\s|^)WALKABOUT')
        x = re.sub(pattern, "WALLABOUT", x)
        pattern = re.compile(r'\sWASH\s|(\s|^)WASTEWATER\s')
        x = re.sub(pattern, "WASHINGTON", x) 
        
        pattern = re.compile(r'\s&\s')
        x = re.sub(pattern, "", x)
    #     pattern = re.compile(r"(\d)ST|ND|RD|TH\b")
    #     x = re.sub(pattern, "", x)

        return x
    
    def space_problem(x):
        # overall spacing problem extra white space
        pattern = re.compile(r'((\w+|\d+)\s\s(\w+|\d+))|((\w+|\d+)\s\s\s(\w+|\d+))')
        x = re.sub(pattern, r"\1 \2", x)

        # change the order of the address, e.g: 4 W to W 4 & AVE after A-Z and Digits
        pattern = re.compile(r'(\w+|\d+)\s(\bN\b|\bW\b|\bS\b|\bE\b)')
        x = re.sub(pattern, r'\2 \1', x)
        pattern = re.compile(r'(AVE)\s(\d+)\s(\d+)')
        x = re.sub(pattern, r'\2-\3 \1', x) 
        pattern = re.compile(r'(AVE)\s([A-Z])')
        x = re.sub(pattern, r'\2 \1', x) 
    #     pattern = re.compile(r'(AVE)\s(\b[A-Z])')
    #     x = re.sub(pattern, r'\2 \1', x) 
    
        return x
    
    def seperate(df, column):
        
        df['original'] = df[column]
        df[column] = df[column].apply(lambda x: str(x.upper()))
        df[column] = df[column].apply(lambda x: Street.name_end(str(x)))
        df[column] = df[column].apply(lambda x: Street.direction(str(x)))
        df[column] = df[column].apply(lambda x: Street.special_characters(str(x)))
        df[column] = df[column].apply(lambda x: Street.number_clean(str(x)))
        df[column] = df[column].apply(lambda x: Street.street_order(str(x)))
        df[column] = df[column].apply(lambda x: Street.name_check(str(x)))
        df[column] = df[column].apply(lambda x: Street.space_problem(str(x)))
        df['new'] = df[column]
        df.drop(column, axis=1, inplace = True)
    
        return df

# %%
pattern = {
    'direction' : r'WEST|EAST|NORTH|SOUTH|\sW\s|\sE\s|\sN\s|\sS\s',
    'end' : r'\sSTREET$|\bSTREET$|\sSTR$|\sSTE$|\sSRT$|\sSR$\s|SRT$|\sSST$|\sSEET$|\sTREET$|\sSHEER$|\sSHEE$|\sSTREE$|\sSREET$|\sREET$|\sSTEE$|\sST$',
    'street_type': r'\sDRIVE$|\sDR$|\sDV$|\sDE$|\sDRV$|\sDRI$|\sDRIV$|\sDRIE$|\sCIRCLE|\sCIR|\sCRL|\sCIRC|\sCR|\sCL|\sCIRCL|\sCICLE|(?<=\s)COURT|CT|CRT|CRT|CTR|(?<=\s)COUR|(?<=\s)COT|(?<=\s)CORT|\sBOULEVARD|\sBVLD|\sBV|\sBLD$|\sBD|\sBL$|\sBLV$|\sROAD|\sRD|\sRAD|\sROD|\sALLEY|\sALY|\sAL|\sALLY|\sALEY|\sALLE|\sAY|\sPLACE|\sPL|\sPLC|\sPLE|\sPC|\sPLAC|\sPLCE|\sPCE|\sPK|\sPRK|\sPRAK|\sPAK|\sPARKWAY|\sPKWY|\sPARKW|\sPWY|\sPKW|\sPRKWY|\sPKWY|\sPKW|\sAPPR|\sAPR|\sAPPROA|\sAPRCH|\sAPPRCH|\sTERRACE|\sTER|\sTERR|\sTRC|\sTRCE|\sTR|\sPLAZA|\sPLZ|\sPLAZ|\sPZ|\sPLZA|\sLANE|\sLN|\sLNE|\sLAN|\sHILL|\sHL|\sHLL|\sHIL|\sHEIGHTS|\sHTS|\sHT|\sHEIGHT|\sHEGHTS|\sHHT|\sHEIGT|\sSLP|\sSLEP|\sSLIIP|\sSLI|\sRON|\sRW|\sROE|\sROOW|\sSQUARE',
#     'number': r'FRIST|FRST|FIRST|ONE|ONE HUNDRED|ONEHUNDRED|HUNDRED|HUDRED|HUNDED|TWO HUNDRED|TWOHUNDRED|TWENTY|TWENTI|TENTI|SECOND|SECORD|SCOND|TWO|THIRTY|THIRTHY|THIRTEY|TIRTY|TRITHY|THRID|THIRD|TIRD|TRIH|THREE|FORTY|FORTH|FOURTHY|FOURT|FRTY|FROTH|FROUTH|FOUR|FIFTY|FIFTHE|FIFTHY|FIFTH|FIFTEY|FIFT|FITY|FIFETH|FIFFTH|FIVE|SIXTY|SXTY|SIXY|SIXTHY|SIXTEY|SIXTH|SXTH|SITH|SIHXT|SIX|SEVENT|SEVENTY|SEVENTEY|SVENTY|SEVENTI|SEVENTH|SVEN|SVENTH|SEVENH|SEVEN|EIGHTY|EIGHTEY|EIGHTE|EIGHTH|EIGHTEH|EITH|EIGHT|EIGHTTH|EIGTH|FIGHT|UNITY|NINTH|NINETY|NINETEY|NINETIETH|NINTY|TENTH|ELEVENTH|TWELFTH|THIRTEENTH|FORTEENTH|FIFTEENTH|SIXTEENTH|SEVENTEENTH|EIGHTEENTH|NINETEENTH|TWENTIETH|TWENTIEFTH|THIRTIETH|THIRTIEFTH|FORTIETH|FOURTIETH|FOURTHENTH|FIFTIETH|SIXTIETH|SEVENTIETH|SEVENTY|EIGHTIETH|EIGHTETH|NINETIETH|NINTIETH',
    'number': r'FRIST|FRST|FIRST|ONE|ONE HUNDRED|ONEHUNDRED|HUNDRED|HUDRED|HUNDED|TWO HUNDRED|TWOHUNDRED|TWENTY|TWENTI|TENTI|SECOND|SECORD|SCOND|TWO|THIRTY|THIRTHY|THIRTEY|TIRTY|TRITHY|THRID|THIRD|TIRD|TRIH|THREE|FORTIETH|FOURTIETH|FORTEENTH|FOURTHENTH|FORTY|FORTH|FOURTHY|FOURT|FRTY|FROTH|FROUTH|FOUR|FIFTIETH|FIFTEENTH|FIFTY|FIFTHE|FIFTHY|FIFTH|FIFTEY|FIFT|FITY|FIFETH|FIFFTH|FIVE|SIXTIETH|SIXTEENTH|SIXTY|SXTY|SIXY|SIXTHY|SIXTEY|SIXTH|SXTH|SITH|SIHXT|SIX|SEVENTIETH|SEVENTY|SEVENTEENTH|SEVENTY|SEVENTEY|SVENTY|SEVENTI|SEVENTH|SVEN|SVENTH|SEVENH|SEVENT|SEVEN|EIGHTIETH|EIGHTETH|EIGHTEENTH|EIGHTY|EIGHTEH|EIGHTEY|EIGHTE|EIGHTH|EITH|EIGHT|EIGHTTH|EIGTH|FIGHT|UNITY|NINETIETH|NINTIETH|NINETEENTH|NINETY|NINETEY|NINETIETH|NINTH|NINTY|TENTH|ELEVENTH|TWELFTH|THIRTEENTH|TWENTIETH|TWENTIEFTH|THIRTIETH|THIRTIEFTH',
    'street_name': r'ALLANTIC|ATLASTA|ALLEM|ALLEN|CROTON|GROTON|AT RINS|BATTIE|BARREE|BESSHLEY|BIRY|B WAY|BWAY|BRAKSWAY|BUSTWICK|BUTTER|BREEVORT|BRENNEL|BROOMES|BROOM|BRANNAS|BROWN|BLACKER|BLENKER|CLAIR|CLISTEN|CHERY|CHRYSTEE|CHRYSTAL|CHTYSTIE|CHRYSTEL|CARRAL|COYAL|COLUMBIN|CAMNON|CROWH|DEVAL|DEBOUCHEL|DAFONT|DEGRAN|DENBO|DEKALB|DELAMERE|DALANEY|DELANEY|DELANCY|ELTHZROTH|ELLSWICK|ELDREDGE|CLARIDGE|ESSEY|FORSYTHE|FLATHISH|GLANCE|GOAST|GREENS|GREENRICH|GAMWICH|HOUTON|HAVES|HAKEY|HEWEY|HICK|HUMBOLOT|HUMBARD|HUMBOLT|JOHOM|KIOP|HEAP|LAY FAY ESTE|LADORATT|LAFYAYETTE|LIRA|LOUMOR|LARMER|LAAVIUK|LAIDLOW|TEX|LEX|REPPERTS|PARLE|MALLE|MYETTE|MC DOUGALL|MC DOUGAL|MCDOUGALL|MC DONOUGH|MANZA|MAREY|MESCOLE|MEASE|MEDDLER|MANGEN|HAULL|MALLERY|NAPOLK|VAST AND|DAK|OLWEN|GERHARD|PUTT|PERROTT|PERROTT PREMPONT|PLAD|PRUFER|PREDIDUNT|PALOKA|RUTHIE|RIDAL|RAYSON|REVENTON|RUALMAINE|RICER SIDE|REDERICK|RENNICK|SELLTOWN|SISH|STUCKER|STATES|SCHAALS|SUMME|SCHOMERDOSA|DOUTH|SONSE|STUYVESTANT|STONPSON|TRAY|TAYLER|WMON|WAR CAREN|VEMON|VANDERLY|VANDERSLIDE|WYONIA|WITKINS|WALLWORTH|WHIPPER|WALLABANK|WALKABOUT|WASH|WASTEWATER'
}

# %%
df['number'] = df['Street address 2'].str.extract('(\d+)')

df['number']
# Out:
# 0        38
# 1       107
# 2        81
# 3       117
# 4        62
#        ...
# 1995    158
# 1996     78
# 1997      8
# 1998    NaN
# 1999    609
# Name: number, Length: 2000, dtype: object

# %%
def search_direction(x):
    
    result = re.findall(pattern['direction'], x)
    return " ".join(result)

def search_end(x):
    result = re.findall(pattern['end'], x)
    return " ".join(result)

def search_street_type(x):
    result = re.findall(pattern['street_type'], x)
    return " ".join(result)

def search_word_number(x):
    result = re.findall(pattern['number'], x)
    return " ".join(result)

def search_street_name(x):
    result = re.findall(pattern['street_name'], x)
    return " ".join(result)

df['direction'] = df['Street address 2'].apply(lambda x : search_direction(x))
df['end'] = df['Street address 2'].apply(lambda x : search_end(x))
df['street_type'] = df['Street address 2'].apply(lambda x : search_street_type(x))
df['word_number'] = df['Street address 2'].apply(lambda x : search_word_number(x))
df['street_name'] = df['Street address 2'].apply(lambda x : search_street_name(x))

# %%
# m = 'WEST SIXTY FIFTH FORTH ST'

# pattern = r'FRIST|FRST|FIRST|ONE|ONE HUNDRED|ONEHUNDRED|HUNDRED|HUDRED|HUNDED|TWO HUNDRED|TWOHUNDRED|TWENTY|TWENTI|TENTI|SECOND|SECORD|SCOND|TWO|THIRTY|THIRTHY|THIRTEY|TIRTY|TRITHY|THRID|THIRD|TIRD|TRIH|THREE|FORTY|FORTH|FOURTHY|FOURT|FRTY|FROTH|FROUTH|FOUR|FIFTY|FIFTHE|FIFTHY|FIFTH|FIFTEY|FIFT|FITY|FIFETH|FIFFTH|FIVE|SIXTY|SXTY|SIXY|SIXTHY|SIXTEY|SIXTH|SXTH|SITH|SIHXT|SIX|SEVENT|SEVENTY|SEVENTEY|SVENTY|SEVENTI|SEVENTH|SVEN|SVENTH|SEVENH|SEVEN|EIGHTY|EIGHTEY|EIGHTE|EIGHTH|EIGHTEH|EITH|EIGHT|EIGHTTH|EIGTH|FIGHT|UNITY|NINTH|NINETY|NINETEY|NINETIETH|NINTY|TENTH|ELEVENTH|TWELFTH|THIRTEENTH|FORTEENTH|FIFTEENTH|SIXTEENTH|SEVENTEENTH|EIGHTEENTH|NINETEENTH|TWENTIETH|TWENTIEFTH|THIRTIETH|THIRTIEFTH|FORTIETH|FOURTIETH|FOURTHENTH|FIFTIETH|SIXTIETH|SEVENTIETH|SEVENTY|EIGHTIETH|EIGHTETH|NINETIETH|NINTIETH'
# # pattern = r'SIXTY|FIFTH|SEVENTH|FORT|FOURTHY'
# a = re.findall(pattern, m)
# a

# %%
print(df['direction'])
print(df['direction'].unique())
# Out:
# 0
# 1       EAST
# 2
# 3       EAST
# 4       WEST
#         ...
# 1995    WEST
# 1996
# 1997
# 1998
# 1999      E
# Name: direction, Length: 2000, dtype: object
# ['' 'EAST' 'WEST' 'SOUTH' ' E ' 'SOUTH WEST' 'WEST NORTH' 'SOUTH  S  WEST'
#  'EAST EAST' ' E   E ']

# %%
print(df['end'])
print(df['end'].unique())
# Out:
# 0        STREET
# 1        STREET
# 2        STREET
# 3        STREET
# 4        STREET
#          ...
# 1995     STREET
# 1996         ST
# 1997
# 1998
# 1999         ST
# Name: end, Length: 2000, dtype: object
# [' STREET' '' ' ST' ' STR' ' STE' 'STREET' ' STREE' ' REET']

# %%
print(df['street_type'])
print(df['street_type'].unique())
# Out:
# 0
# 1
# 2
# 3
# 4
#        ..
# 1995
# 1996
# 1997
# 1998
# 1999
# Name: street_type, Length: 2000, dtype: object
# ['' ' PLACE' ' SQUARE' ' ROAD' ' LANE' ' CL' ' DRIVE' ' AL' ' TERRACE']

# %%
print(df['word_number'])
print(df['word_number'].unique())
# Out:
# 0
# 1
# 2
# 3
# 4
#        ..
# 1995
# 1996
# 1997
# 1998
# 1999
# Name: word_number, Length: 2000, dtype: object
# ['' 'FIFTH' 'SIXTY FIFTH' 'NINTY FIRST' 'THIRD' 'SIXTY SECOND' 'NINTH'
#  'SECOND' 'EIGHTH' 'SEVENTH' 'FIFTY FOURT' 'SIXTH' 'FIFTY FIFTH'
#  'THIRTY THIRD' 'SIXTIETH' 'FIRST' 'ONE' 'TWENTY EIGHT' 'TENTH'
#  'ONE HUNDRED SEVEN' 'FOURT' 'ONE TWENTY NINTH' 'FOURT NINTH' 'THIRTEENTH'
#  'TWENTY THIRD' 'FIFTY THIRD' 'SIXTY THIRD' 'NINETY THIRD' 'SEVENTY THIRD'
#  'TWENTY EIGHTH' 'ONE HUNDRED SEVENTEENTH' 'ONE HUNDRED THIRTY'
#  'EIGHTY EIGHTH' 'THIRTY EIGHT' 'TWELFTH' 'EIGHTY NINTH' 'NINTY NINTH'
#  'THIRTY FIRST' 'FIFTY SECOND' 'SEVENTIETH' 'THIRTY SEVENTH' 'FORTIETH'
#  'FORTY FIRST' 'ONE HUNDRED FOURT' 'EIGTH' 'NINTY SIXTH'
#  'ONE HUNDRED FIFTH' 'FIFTY SEVENTH' 'EIGHT' 'ELEVENTH' 'FIFTY FIRST'
#  'ONE HUNDRED TWENTY FIFT' 'SEVENTY FOURT' 'FOURT FIFTH' 'SEVENTEENTH'
#  'UNITY FIFTH' 'TWENTY SIXTH' 'ONE HUNDRED TWENTI' 'NINETY SIXTH'
#  'ONE HUNDRED EIGHT' 'EIGHTEENTH' 'FRIST' 'TWENTY FIFTH' 'SEVENTY'
#  'ONE HUNDRED' 'FIFTEENTH' 'FIFTIETH' 'FORTY NINTH' 'ONE HUNDRED SECOND'
#  'TWENTY FIRST' 'SEVENTY SECOND' 'SEVENTY SEVENTH' 'FORTY SEVENTH'
#  'TWENTY FOURT' 'ONE HUNDRED THIRTY THIRD' 'ONE HUNDRED SIXTH'
#  'SEVENTH FOURT' 'SEVEN FIFTH' 'FORTY SECOND' 'ONE HUNDRED EIGHTEENTH'
#  'NINETY FOURT' 'SEVENTY FIFTH' 'EIGHTY FIFTH' 'EIGHTY THIRD'
#  'TWENTY NINTH' 'EIGHTY SEVENTH' 'EIGHTY SECOND'
#  'ONE HUNDRED TWENTY FIRST' 'EIGHTIETH' 'SEVEN' 'THIRTY FOURT']

# %%
print(df['street_name'])
print(df['street_name'].unique())
# Out:
# 0
# 1
# 2
# 3
# 4
#        ...
# 1995
# 1996
# 1997
# 1998    LEX
# 1999
# Name: street_name, Length: 2000, dtype: object
# ['' 'CHRYSTAL' 'LEX' 'WASH' 'BROOM' 'ALLEN' 'FORSYTHE' 'RENNICK' 'CHERY'
#  'HOUTON' 'BLACKER']

# %%
df
# Out:
#      Record type Standardized township (string)  County 2  \
# 0              H                      MANHATTAN       610
# 1              H                      MANHATTAN       610
# 2              H                      MANHATTAN       610
# 3              H                      MANHATTAN       610
# 4              H                      MANHATTAN       610
# ...          ...                            ...       ...
# 1995           H                      MANHATTAN       610
# 1996           H                      MANHATTAN       610
# 1997           H                      MANHATTAN       610
# 1998           H                      MANHATTAN       610
# 1999           H                      MANHATTAN       610
#
#       Enumeration district 2  Consistent historical data person identifier  \
# 0                       1256                                           NaN
# 1                        339                                           NaN
# 2                       1043                                           NaN
# 3                        292                                           NaN
# 4                       1318                                           NaN
# ...                      ...                                           ...
# 1995                     691                                           NaN
# 1996                    1036                                           NaN
# 1997                    1202                                           NaN
# 1998                     425                                           NaN
# 1999                     939                                           NaN
#
#       Dwelling sequence number  Dwelling serial number  \
# 0                          NaN                   60496
# 1                          NaN                 1943060
# 2                          NaN                  477699
# 3                          NaN                  217548
# 4                          NaN                  739265
# ...                        ...                     ...
# 1995                       NaN                   53635
# 1996                       NaN                  474555
# 1997                       NaN                  511291
# 1998                       NaN                  439107
# 1999                       NaN                 1338784
#
#       Dwelling serial number 2  Household sequence within dwelling  \
# 0                          661                                  38
# 1                        21190                                  18
# 2                         5196                                  50
# 3                         2408                                  92
# 4                         8103                                  25
# ...                        ...                                 ...
# 1995                       585                                   9
# 1996                      5164                                  39
# 1997                      5578                                  53
# 1998                      4767                                  16
# 1999                     14582                                   8
#
#       Household sequence within dwelling, 8 digit  ...  \
# 0                                           60496  ...
# 1                                         1943060  ...
# 2                                          477699  ...
# 3                                          217548  ...
# 4                                          739265  ...
# ...                                           ...  ...
# 1995                                        53635  ...
# 1996                                       474555  ...
# 1997                                       511291  ...
# 1998                                       439107  ...
# 1999                                      1338784  ...
#
#       Number of families in household  \
# 0                                   2
# 1                                   1
# 2                                   1
# 3                                   2
# 4                                   1
# ...                               ...
# 1995                                1
# 1996                                1
# 1997                                1
# 1998                                1
# 1999                                1
#
#       Number of person records in household, before large group quarters were split up  (100% datasets)  \
# 0                                                     7
# 1                                                     2
# 2                                                     5
# 3                                                     4
# 4                                                     1
# ...                                                 ...
# 1995                                                  5
# 1996                                                  3
# 1997                                                  2
# 1998                                                  4
# 1999                                                  5
#
#       House number   Street address 2  number  direction      end  \
# 0              NaN          38 STREET      38              STREET
# 1              NaN  EAST 107TH STREET     107       EAST   STREET
# 2              337        81ST STREET      81              STREET
# 3              NaN  EAST 117TH STREET     117       EAST   STREET
# 4              NaN   WEST 62ND STREET      62       WEST   STREET
# ...            ...                ...     ...        ...      ...
# 1995           NaN    WEST 158 STREET     158       WEST   STREET
# 1996           NaN          E 78TH ST      78                  ST
# 1997           NaN            8TH AVE       8
# 1998           NaN      LEXINGTON AVE     NaN
# 1999           NaN      609 E 14TH ST     609         E        ST
#
#       street_type  word_number street_name
# 0
# 1
# 2
# 3
# 4
# ...           ...          ...         ...
# 1995
# 1996
# 1997
# 1998                                   LEX
# 1999
#
# [2000 rows x 27 columns]

# %%
def search_direction(text):
    result = re.findall(r'WEST|EAST|NORTH|SOUTH|\sW\s|\sE\s|\sN\s|\sS\s', text)
    return " ".join(result)

# %%
x = 'WEST ONE HUNDRED AND SEVEN STREET'
a = re.findall('WEST', x)[0]
a
# Out:
# 'WEST'

# %% [markdown]
# regular expression in R:
# - https://rstudio-pubs-static.s3.amazonaws.com/74603_76cd14d5983f47408fdf0b323550b846.html
# - https://cran.r-project.org/web/packages/stringr/vignettes/regular-expressions.html
#
# regular expression in Python:
# - https://www.bogotobogo.com/python/python_regularExpressions.php#:~:text=Well%2C%20%5CD%20matches%20any%20character,try%20to%20match%20different%20separators.
#
# Quite useful regular expression extract web:
# - https://regex101.com/r/rzNgTL/1
